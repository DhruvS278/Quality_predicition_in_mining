# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("C://Users//DHRUV.DESKTOP-KRBVT38//OneDrive//Desktop//Work//Project//data science//Kaggle//ntcc intern project//Project10_Quality Prediction in a Mining Process//Project10//Project10_Quality Prediction in a Mining Process//MiningProcess_Flotation_Plant_Database.csv",parse_dates=['date'],
    infer_datetime_format=True,
    decimal=',')
df.head()
# Out:
#                  date  % Iron Feed  % Silica Feed  Starch Flow  Amina Flow  \
# 0 2017-03-10 01:00:00         55.2          16.98      3019.53     557.434
# 1 2017-03-10 01:00:00         55.2          16.98      3024.41     563.965
# 2 2017-03-10 01:00:00         55.2          16.98      3043.46     568.054
# 3 2017-03-10 01:00:00         55.2          16.98      3047.36     568.665
# 4 2017-03-10 01:00:00         55.2          16.98      3033.69     558.167
#
#    Ore Pulp Flow  Ore Pulp pH  Ore Pulp Density  Flotation Column 01 Air Flow  \
# 0        395.713      10.0664              1.74                       249.214
# 1        397.383      10.0672              1.74                       249.719
# 2        399.668      10.0680              1.74                       249.741
# 3        397.939      10.0689              1.74                       249.917
# 4        400.254      10.0697              1.74                       250.203
#
#    Flotation Column 02 Air Flow  ...  Flotation Column 07 Air Flow  \
# 0                       253.235  ...                       250.884
# 1                       250.532  ...                       248.994
# 2                       247.874  ...                       248.071
# 3                       254.487  ...                       251.147
# 4                       252.136  ...                       248.928
#
#    Flotation Column 01 Level  Flotation Column 02 Level  \
# 0                    457.396                    432.962
# 1                    451.891                    429.560
# 2                    451.240                    468.927
# 3                    452.441                    458.165
# 4                    452.441                    452.900
#
#    Flotation Column 03 Level  Flotation Column 04 Level  \
# 0                    424.954                    443.558
# 1                    432.939                    448.086
# 2                    434.610                    449.688
# 3                    442.865                    446.210
# 4                    450.523                    453.670
#
#    Flotation Column 05 Level  Flotation Column 06 Level  \
# 0                    502.255                    446.370
# 1                    496.363                    445.922
# 2                    484.411                    447.826
# 3                    471.411                    437.690
# 4                    462.598                    443.682
#
#    Flotation Column 07 Level  % Iron Concentrate  % Silica Concentrate
# 0                    523.344               66.91                  1.31
# 1                    498.075               66.91                  1.31
# 2                    458.567               66.91                  1.31
# 3                    427.669               66.91                  1.31
# 4                    425.679               66.91                  1.31
#
# [5 rows x 24 columns]

# %%
df
# Out:
#                       date  % Iron Feed  % Silica Feed  Starch Flow  \
# 0      2017-03-10 01:00:00        55.20          16.98      3019.53
# 1      2017-03-10 01:00:00        55.20          16.98      3024.41
# 2      2017-03-10 01:00:00        55.20          16.98      3043.46
# 3      2017-03-10 01:00:00        55.20          16.98      3047.36
# 4      2017-03-10 01:00:00        55.20          16.98      3033.69
# ...                    ...          ...            ...          ...
# 737448 2017-09-09 23:00:00        49.75          23.20      2710.94
# 737449 2017-09-09 23:00:00        49.75          23.20      2692.01
# 737450 2017-09-09 23:00:00        49.75          23.20      2692.20
# 737451 2017-09-09 23:00:00        49.75          23.20      1164.12
# 737452 2017-09-09 23:00:00        49.75          23.20      1164.12
#
#         Amina Flow  Ore Pulp Flow  Ore Pulp pH  Ore Pulp Density  \
# 0          557.434        395.713     10.06640           1.74000
# 1          563.965        397.383     10.06720           1.74000
# 2          568.054        399.668     10.06800           1.74000
# 3          568.665        397.939     10.06890           1.74000
# 4          558.167        400.254     10.06970           1.74000
# ...            ...            ...          ...               ...
# 737448     441.052        386.570      9.62129           1.65365
# 737449     473.436        384.939      9.62063           1.65352
# 737450     500.488        383.496      9.61874           1.65338
# 737451     491.548        384.976      9.61686           1.65324
# 737452     468.019        384.801      9.61497           1.65310
#
#         Flotation Column 01 Air Flow  Flotation Column 02 Air Flow  ...  \
# 0                            249.214                       253.235  ...
# 1                            249.719                       250.532  ...
# 2                            249.741                       247.874  ...
# 3                            249.917                       254.487  ...
# 4                            250.203                       252.136  ...
# ...                              ...                           ...  ...
# 737448                       302.344                       298.786  ...
# 737449                       303.013                       301.879  ...
# 737450                       303.662                       307.397  ...
# 737451                       302.550                       301.959  ...
# 737452                       300.355                       292.865  ...
#
#         Flotation Column 07 Air Flow  Flotation Column 01 Level  \
# 0                            250.884                    457.396
# 1                            248.994                    451.891
# 2                            248.071                    451.240
# 3                            251.147                    452.441
# 4                            248.928                    452.441
# ...                              ...                        ...
# 737448                       313.695                    392.160
# 737449                       236.700                    401.505
# 737450                       225.879                    408.899
# 737451                       308.115                    405.107
# 737452                       308.115                    413.754
#
#         Flotation Column 02 Level  Flotation Column 03 Level  \
# 0                         432.962                    424.954
# 1                         429.560                    432.939
# 2                         468.927                    434.610
# 3                         458.165                    442.865
# 4                         452.900                    450.523
# ...                           ...                        ...
# 737448                    430.702                    872.008
# 737449                    404.616                    864.409
# 737450                    399.316                    867.598
# 737451                    466.832                    876.591
# 737452                    514.143                    881.323
#
#         Flotation Column 04 Level  Flotation Column 05 Level  \
# 0                         443.558                    502.255
# 1                         448.086                    496.363
# 2                         449.688                    484.411
# 3                         446.210                    471.411
# 4                         453.670                    462.598
# ...                           ...                        ...
# 737448                    418.725                    497.548
# 737449                    418.377                    506.398
# 737450                    419.531                    503.414
# 737451                    407.299                    502.301
# 737452                    378.969                    500.100
#
#         Flotation Column 06 Level  Flotation Column 07 Level  \
# 0                         446.370                    523.344
# 1                         445.922                    498.075
# 2                         447.826                    458.567
# 3                         437.690                    427.669
# 4                         443.682                    425.679
# ...                           ...                        ...
# 737448                    446.357                    416.892
# 737449                    372.995                    426.337
# 737450                    336.035                    433.130
# 737451                    340.844                    433.966
# 737452                    374.354                    441.182
#
#         % Iron Concentrate  % Silica Concentrate
# 0                    66.91                  1.31
# 1                    66.91                  1.31
# 2                    66.91                  1.31
# 3                    66.91                  1.31
# 4                    66.91                  1.31
# ...                    ...                   ...
# 737448               64.27                  1.71
# 737449               64.27                  1.71
# 737450               64.27                  1.71
# 737451               64.27                  1.71
# 737452               64.27                  1.71
#
# [737453 rows x 24 columns]

# %%
df.isna().any()
# Out:
# date                            False
# % Iron Feed                     False
# % Silica Feed                   False
# Starch Flow                     False
# Amina Flow                      False
# Ore Pulp Flow                   False
# Ore Pulp pH                     False
# Ore Pulp Density                False
# Flotation Column 01 Air Flow    False
# Flotation Column 02 Air Flow    False
# Flotation Column 03 Air Flow    False
# Flotation Column 04 Air Flow    False
# Flotation Column 05 Air Flow    False
# Flotation Column 06 Air Flow    False
# Flotation Column 07 Air Flow    False
# Flotation Column 01 Level       False
# Flotation Column 02 Level       False
# Flotation Column 03 Level       False
# Flotation Column 04 Level       False
# Flotation Column 05 Level       False
# Flotation Column 06 Level       False
# Flotation Column 07 Level       False
# % Iron Concentrate              False
# % Silica Concentrate            False
# dtype: bool

# %% [markdown]
# ```NO NULL VALUE PRESENT```

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 737453 entries, 0 to 737452
# Data columns (total 24 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   date                          737453 non-null  datetime64[ns]
#  1   % Iron Feed                   737453 non-null  float64
#  2   % Silica Feed                 737453 non-null  float64
#  3   Starch Flow                   737453 non-null  float64
#  4   Amina Flow                    737453 non-null  float64
#  5   Ore Pulp Flow                 737453 non-null  float64
#  6   Ore Pulp pH                   737453 non-null  float64
#  7   Ore Pulp Density              737453 non-null  float64
#  8   Flotation Column 01 Air Flow  737453 non-null  float64
#  9   Flotation Column 02 Air Flow  737453 non-null  float64
#  10  Flotation Column 03 Air Flow  737453 non-null  float64
#  11  Flotation Column 04 Air Flow  737453 non-null  float64
#  12  Flotation Column 05 Air Flow  737453 non-null  float64
#  13  Flotation Column 06 Air Flow  737453 non-null  float64
#  14  Flotation Column 07 Air Flow  737453 non-null  float64
#  15  Flotation Column 01 Level     737453 non-null  float64
#  16  Flotation Column 02 Level     737453 non-null  float64
#  17  Flotation Column 03 Level     737453 non-null  float64
#  18  Flotation Column 04 Level     737453 non-null  float64
#  19  Flotation Column 05 Level     737453 non-null  float64
#  20  Flotation Column 06 Level     737453 non-null  float64
#  21  Flotation Column 07 Level     737453 non-null  float64
#  22  % Iron Concentrate            737453 non-null  float64
#  23  % Silica Concentrate          737453 non-null  float64
# dtypes: datetime64[ns](1), float64(23)
# memory usage: 135.0 MB

# %%
df.describe()
# Out:
#          % Iron Feed  % Silica Feed    Starch Flow     Amina Flow  \
# count  737453.000000  737453.000000  737453.000000  737453.000000
# mean       56.294739      14.651716    2869.140569     488.144697
# std         5.157744       6.807439    1215.203734      91.230534
# min        42.740000       1.310000       0.002026     241.669000
# 25%        52.670000       8.940000    2076.320000     431.796000
# 50%        56.080000      13.850000    3018.430000     504.393000
# 75%        59.720000      19.600000    3727.730000     553.257000
# max        65.780000      33.400000    6300.230000     739.538000
#
#        Ore Pulp Flow    Ore Pulp pH  Ore Pulp Density  \
# count  737453.000000  737453.000000     737453.000000
# mean      397.578372       9.767639          1.680380
# std         9.699785       0.387007          0.069249
# min       376.249000       8.753340          1.519820
# 25%       394.264000       9.527360          1.647310
# 50%       399.249000       9.798100          1.697600
# 75%       402.968000      10.038000          1.728330
# max       418.641000      10.808100          1.853250
#
#        Flotation Column 01 Air Flow  Flotation Column 02 Air Flow  \
# count                 737453.000000                 737453.000000
# mean                     280.151856                    277.159965
# std                       29.621288                     30.149357
# min                      175.510000                    175.156000
# 25%                      250.281000                    250.457000
# 50%                      299.344000                    296.223000
# 75%                      300.149000                    300.690000
# max                      373.871000                    375.992000
#
#        Flotation Column 03 Air Flow  ...  Flotation Column 07 Air Flow  \
# count                 737453.000000  ...                 737453.000000
# mean                     281.082397  ...                    290.754856
# std                       28.558268  ...                     28.670105
# min                      176.469000  ...                    185.962000
# 25%                      250.855000  ...                    256.302000
# 50%                      298.696000  ...                    299.011000
# 75%                      300.382000  ...                    301.904000
# max                      364.346000  ...                    371.593000
#
#        Flotation Column 01 Level  Flotation Column 02 Level  \
# count              737453.000000              737453.000000
# mean                  520.244823                 522.649555
# std                   131.014924                 128.165050
# min                   149.218000                 210.752000
# 25%                   416.978000                 441.883000
# 50%                   491.878000                 495.956000
# 75%                   594.114000                 595.464000
# max                   862.274000                 828.919000
#
#        Flotation Column 03 Level  Flotation Column 04 Level  \
# count              737453.000000              737453.000000
# mean                  531.352662                 420.320973
# std                   150.842164                  91.794432
# min                   126.255000                 162.201000
# 25%                   411.325000                 356.679000
# 50%                   494.318000                 411.974000
# 75%                   601.249000                 485.549000
# max                   886.822000                 680.359000
#
#        Flotation Column 05 Level  Flotation Column 06 Level  \
# count              737453.000000              737453.000000
# mean                  425.251706                 429.941018
# std                    84.535822                  89.862225
# min                   166.991000                 155.841000
# 25%                   357.653000                 358.497000
# 50%                   408.773000                 424.664575
# 75%                   484.329000                 492.684000
# max                   675.644000                 698.861000
#
#        Flotation Column 07 Level  % Iron Concentrate  % Silica Concentrate
# count              737453.000000       737453.000000         737453.000000
# mean                  421.021231           65.050068              2.326763
# std                    84.891491            1.118645              1.125554
# min                   175.349000           62.050000              0.600000
# 25%                   356.772000           64.370000              1.440000
# 50%                   411.065000           65.210000              2.000000
# 75%                   476.465000           65.860000              3.010000
# max                   659.902000           68.010000              5.530000
#
# [8 rows x 23 columns]

# %%
col_mean = {}
col_std = {}
description = df.describe()
for i in df.columns:
    if df[i].dtype == "float64":
        col_mean[i] = df.describe()[i]['mean']
        col_std[i] = df.describe()[i]['std']

# %%
df[i].dtype
# Out:
# dtype('float64')

# %%
col_mean, col_std
# Out:
# ({'% Iron Feed': 56.29473906811692,
#   '% Silica Feed': 14.65171555339798,
#   'Starch Flow': 2869.1405694542955,
#   'Amina Flow': 488.14469722409444,
#   'Ore Pulp Flow': 397.57837171046833,
#   'Ore Pulp pH': 9.767638747852406,
#   'Ore Pulp Density': 1.6803796856003073,
#   'Flotation Column 01 Air Flow': 280.15185617456314,
#   'Flotation Column 02 Air Flow': 277.1599652228685,
#   'Flotation Column 03 Air Flow': 281.08239727752147,
#   'Flotation Column 04 Air Flow': 299.4477935583694,
#   'Flotation Column 05 Air Flow': 299.91781411764566,
#   'Flotation Column 06 Air Flow': 292.07148503904665,
#   'Flotation Column 07 Air Flow': 290.7548562586361,
#   'Flotation Column 01 Level': 520.244822748026,
#   'Flotation Column 02 Level': 522.6495545316106,
#   'Flotation Column 03 Level': 531.3526623255987,
#   'Flotation Column 04 Level': 420.3209730796405,
#   'Flotation Column 05 Level': 425.2517058999015,
#   'Flotation Column 06 Level': 429.9410177177395,
#   'Flotation Column 07 Level': 421.02123055367605,
#   '% Iron Concentrate': 65.05006799077364,
#   '% Silica Concentrate': 2.326763251352968},
#  {'% Iron Feed': 5.157744142640885,
#   '% Silica Feed': 6.80743869107689,
#   'Starch Flow': 1215.2037343666975,
#   'Amina Flow': 91.23053356507404,
#   'Ore Pulp Flow': 9.699784987199482,
#   'Ore Pulp pH': 0.387007304156314,
#   'Ore Pulp Density': 0.06924882859568555,
#   'Flotation Column 01 Air Flow': 29.621287562414707,
#   'Flotation Column 02 Air Flow': 30.14935669786789,
#   'Flotation Column 03 Air Flow': 28.55826846952187,
#   'Flotation Column 04 Air Flow': 2.5725375588678543,
#   'Flotation Column 05 Air Flow': 3.636579266894525,
#   'Flotation Column 06 Air Flow': 30.21780405213974,
#   'Flotation Column 07 Air Flow': 28.67010500329334,
#   'Flotation Column 01 Level': 131.01492358079008,
#   'Flotation Column 02 Level': 128.16505049432595,
#   'Flotation Column 03 Level': 150.8421644099908,
#   'Flotation Column 04 Level': 91.79443158750132,
#   'Flotation Column 05 Level': 84.53582198906615,
#   'Flotation Column 06 Level': 89.86222527703632,
#   'Flotation Column 07 Level': 84.89149071708283,
#   '% Iron Concentrate': 1.1186447188671842,
#   '% Silica Concentrate': 1.1255535947546034})

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, r2_score

# %%
plt.figure(figsize=(25,25))
sns.heatmap(df.corr(), annot=True)
plt.title("Correlation Matrix")
plt.savefig("CorrelationHeatmap.png")
plt.show()
# Out:
# C:\Users\DHRUV.DESKTOP-KRBVT38\AppData\Local\Temp\ipykernel_6908\1552699091.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot=True)

# %%
df.groupby(df['date']).count()
# Out:
#                      % Iron Feed  % Silica Feed  Starch Flow  Amina Flow  \
# date
# 2017-03-10 01:00:00          174            174          174         174
# 2017-03-10 02:00:00          180            180          180         180
# 2017-03-10 03:00:00          180            180          180         180
# 2017-03-10 04:00:00          180            180          180         180
# 2017-03-10 05:00:00          180            180          180         180
# ...                          ...            ...          ...         ...
# 2017-09-09 19:00:00          180            180          180         180
# 2017-09-09 20:00:00          180            180          180         180
# 2017-09-09 21:00:00          180            180          180         180
# 2017-09-09 22:00:00          180            180          180         180
# 2017-09-09 23:00:00          180            180          180         180
#
#                      Ore Pulp Flow  Ore Pulp pH  Ore Pulp Density  \
#
#                      Flotation Column 06 Level  Flotation Column 07 Level  \
# date
# 2017-03-10 01:00:00                        174                        174
# 2017-03-10 02:00:00                        180                        180
# 2017-03-10 03:00:00                        180                        180
# 2017-03-10 04:00:00                        180                        180
# 2017-03-10 05:00:00                        180                        180
# ...                                        ...                        ...
# 2017-09-09 19:00:00                        180                        180
# 2017-09-09 20:00:00                        180                        180
# 2017-09-09 21:00:00                        180                        180
# 2017-09-09 22:00:00                        180                        180
# 2017-09-09 23:00:00                        180                        180
#
#                      % Iron Concentrate  % Silica Concentrate
# date
# 2017-03-10 01:00:00                 174                   174
# 2017-03-10 02:00:00                 180                   180
# 2017-03-10 03:00:00                 180                   180
# 2017-03-10 04:00:00                 180                   180
# 2017-03-10 05:00:00                 180                   180
# ...                                 ...                   ...
# 2017-09-09 19:00:00                 180                   180
# 2017-09-09 20:00:00                 180                   180
# 2017-09-09 21:00:00                 180                   180
# 2017-09-09 22:00:00                 180                   180
# 2017-09-09 23:00:00                 180                   180
#
# [4097 rows x 23 columns]

# %%
dfnew = df.set_index('date').resample('24H').count()
plt.plot(dfnew['% Silica Concentrate'])
print(dfnew[dfnew['% Silica Concentrate']==0]['% Silica Concentrate'])
# Out:
# date
# 2017-03-17    0
# 2017-03-18    0
# 2017-03-19    0
# 2017-03-20    0
# 2017-03-21    0
# 2017-03-22    0
# 2017-03-23    0
# 2017-03-24    0
# 2017-03-25    0
# 2017-03-26    0
# 2017-03-27    0
# 2017-03-28    0
# Freq: 24H, Name: % Silica Concentrate, dtype: int64

# %%
dfnew.loc['2017-03-28']
# Out:
# % Iron Feed                     0
# % Silica Feed                   0
# Starch Flow                     0
# Amina Flow                      0
# Ore Pulp Flow                   0
# Ore Pulp pH                     0
# Ore Pulp Density                0
# Flotation Column 01 Air Flow    0
# Flotation Column 02 Air Flow    0
# Flotation Column 03 Air Flow    0
# Flotation Column 04 Air Flow    0
# Flotation Column 05 Air Flow    0
# Flotation Column 06 Air Flow    0
# Flotation Column 07 Air Flow    0
# Flotation Column 01 Level       0
# Flotation Column 02 Level       0
# Flotation Column 03 Level       0
# Flotation Column 04 Level       0
# Flotation Column 05 Level       0
# Flotation Column 06 Level       0
# Flotation Column 07 Level       0
# % Iron Concentrate              0
# % Silica Concentrate            0
# Name: 2017-03-28 00:00:00, dtype: int64

# %%
mask = df['date'] > '2017-03-28 01:00:00'
data = df.loc[mask]

# %%
data = data.set_index('date')

# %%
plt.figure(figsize=(20,10))
plt.plot(data['% Silica Concentrate'][:30000])

# %%
plt.figure(figsize=(20,10))
plt.plot(data['% Iron Concentrate'][:30000])

# %%
data = data.resample('H').first()

# %%
X = data.drop(['% Iron Concentrate','% Silica Concentrate'], axis=1)
Y = data[['% Iron Concentrate','% Silica Concentrate']]

# %%
X
# Out:
#                      % Iron Feed  % Silica Feed  Starch Flow  Amina Flow  \
    dftest = adfuller(timeseries, autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    print (dfoutput)

# %%
for i in X.columns:
    adf_test(X[i], i)
# Out:
# Results of Dickey-Fuller Test: % Iron Feed
# Test Statistic                   -3.815239
# p-value                           0.002755
# #Lags Used                       24.000000
# Number of Observations Used    3923.000000
# Critical Value (1%)              -3.432018
# Critical Value (5%)              -2.862277
# Critical Value (10%)             -2.567162
# dtype: float64
# Results of Dickey-Fuller Test: % Silica Feed
# Test Statistic                   -4.520901
# p-value                           0.000180
# #Lags Used                       27.000000
# Number of Observations Used    3920.000000
# Critical Value (1%)              -3.432019
# Critical Value (5%)              -2.862278
# Critical Value (10%)             -2.567163
# dtype: float64
# Results of Dickey-Fuller Test: Starch Flow
# Test Statistic                -5.677135e+00
# p-value                        8.652851e-07
# #Lags Used                     2.900000e+01
# Number of Observations Used    3.918000e+03
# Critical Value (1%)           -3.432020e+00
# Critical Value (5%)           -2.862278e+00
# Critical Value (10%)          -2.567163e+00
# dtype: float64
# Results of Dickey-Fuller Test: Amina Flow
# Test Statistic                -1.559144e+01
# p-value                        1.877945e-28
# #Lags Used                     5.000000e+00
# Number of Observations Used    3.942000e+03
# Critical Value (1%)           -3.432010e+00
# Critical Value (5%)           -2.862273e+00
# Critical Value (10%)          -2.567160e+00
# dtype: float64
# Results of Dickey-Fuller Test: Ore Pulp Flow
# Test Statistic                   -4.075260
# p-value                           0.001064
# #Lags Used                       31.000000
# Number of Observations Used    3916.000000
# Critical Value (1%)              -3.432021
# Critical Value (5%)              -2.862278
# Critical Value (10%)             -2.567163
# dtype: float64
# Results of Dickey-Fuller Test: Ore Pulp pH
# Test Statistic                   -4.875803
# p-value                           0.000039
# #Lags Used                       24.000000
# Number of Observations Used    3923.000000
# Critical Value (1%)              -3.432018
# Critical Value (5%)              -2.862277
# Critical Value (10%)             -2.567162
# dtype: float64
# Results of Dickey-Fuller Test: Ore Pulp Density
# Test Statistic                -1.572912e+01
# p-value                        1.295882e-28
# #Lags Used                     5.000000e+00
# Number of Observations Used    3.942000e+03
# Critical Value (1%)           -3.432010e+00
# Critical Value (5%)           -2.862273e+00
# Critical Value (10%)          -2.567160e+00
# dtype: float64
# Results of Dickey-Fuller Test: Flotation Column 01 Air Flow
# Test Statistic                   -4.735958
# p-value                           0.000072
# #Lags Used                       19.000000
# Number of Observations Used    3928.000000
# Critical Value (1%)              -3.432016
# Critical Value (5%)              -2.862276
# Critical Value (10%)             -2.567162
# dtype: float64
# Results of Dickey-Fuller Test: Flotation Column 02 Air Flow
# Test Statistic                   -5.011535
# p-value                           0.000021
# #Lags Used                       24.000000
# Number of Observations Used    3923.000000
# Critical Value (1%)              -3.432018
# Critical Value (5%)              -2.862277
# Critical Value (10%)             -2.567162
# dtype: float64
# Results of Dickey-Fuller Test: Flotation Column 03 Air Flow
# Test Statistic                   -4.222389
# p-value                           0.000604
# #Lags Used                       20.000000
# Number of Observations Used    3927.000000
# Critical Value (1%)              -3.432016
# Critical Value (5%)              -2.862276
# Critical Value (10%)             -2.567162
# dtype: float64
# Results of Dickey-Fuller Test: Flotation Column 04 Air Flow
# Test Statistic                   -3.781477
# p-value                           0.003103
# #Lags Used                       18.000000
# Number of Observations Used    3929.000000
# Critical Value (1%)              -3.432015
# Critical Value (5%)              -2.862276
# Critical Value (10%)             -2.567162
# dtype: float64
# Results of Dickey-Fuller Test: Flotation Column 05 Air Flow
# Test Statistic                   -4.695241
# p-value                           0.000086
# #Lags Used                       22.000000
# Number of Observations Used    3925.000000
# Critical Value (1%)              -3.432017
# Critical Value (5%)              -2.862277
# Critical Value (10%)             -2.567162
# dtype: float64
# Results of Dickey-Fuller Test: Flotation Column 06 Air Flow
# Test Statistic                   -4.719898
# p-value                           0.000077
# #Lags Used                       24.000000
# Number of Observations Used    3923.000000
# Critical Value (1%)              -3.432018
# Critical Value (5%)              -2.862277
# Critical Value (10%)             -2.567162
# dtype: float64
# Results of Dickey-Fuller Test: Flotation Column 07 Air Flow
# Test Statistic                   -4.916156
# p-value                           0.000032
# #Lags Used                       27.000000
# Number of Observations Used    3920.000000
# Critical Value (1%)              -3.432019
# Critical Value (5%)              -2.862278
# Critical Value (10%)             -2.567163
# dtype: float64
# Results of Dickey-Fuller Test: Flotation Column 01 Level
# Test Statistic                   -5.460181
# p-value                           0.000003
# #Lags Used                       31.000000
# Number of Observations Used    3916.000000
# Critical Value (1%)              -3.432021
# Critical Value (5%)              -2.862278
# Critical Value (10%)             -2.567163
# dtype: float64
# Results of Dickey-Fuller Test: Flotation Column 02 Level
# Test Statistic                -5.912740e+00
# p-value                        2.615533e-07
# #Lags Used                     2.300000e+01
# Number of Observations Used    3.924000e+03
# Critical Value (1%)           -3.432018e+00
# Critical Value (5%)           -2.862277e+00
# Critical Value (10%)          -2.567162e+00
# dtype: float64
# Results of Dickey-Fuller Test: Flotation Column 03 Level
# Test Statistic                -6.777615e+00
# p-value                        2.547001e-09
# #Lags Used                     2.300000e+01
# Number of Observations Used    3.924000e+03
# Critical Value (1%)           -3.432018e+00
# Critical Value (5%)           -2.862277e+00
# Critical Value (10%)          -2.567162e+00
# dtype: float64
# Results of Dickey-Fuller Test: Flotation Column 04 Level
# Test Statistic                -1.145415e+01
# p-value                        5.761350e-21
# #Lags Used                     6.000000e+00
# Number of Observations Used    3.941000e+03
# Critical Value (1%)           -3.432010e+00
# Critical Value (5%)           -2.862274e+00
# Critical Value (10%)          -2.567161e+00
# dtype: float64
# Results of Dickey-Fuller Test: Flotation Column 05 Level
# Test Statistic                -1.039459e+01
# p-value                        1.980326e-18
# #Lags Used                     8.000000e+00
# Number of Observations Used    3.939000e+03
# Critical Value (1%)           -3.432011e+00
# Critical Value (5%)           -2.862274e+00
# Critical Value (10%)          -2.567161e+00
# dtype: float64
# Results of Dickey-Fuller Test: Flotation Column 06 Level
# Test Statistic                -7.980791e+00
# p-value                        2.626840e-12
# #Lags Used                     2.600000e+01
# Number of Observations Used    3.921000e+03
# Critical Value (1%)           -3.432019e+00
# Critical Value (5%)           -2.862277e+00
# Critical Value (10%)          -2.567163e+00
# dtype: float64
# Results of Dickey-Fuller Test: Flotation Column 07 Level
# Test Statistic                -1.054164e+01
# p-value                        8.619727e-19
# #Lags Used                     6.000000e+00
# Number of Observations Used    3.941000e+03
# Critical Value (1%)           -3.432010e+00
# Critical Value (5%)           -2.862274e+00
# Critical Value (10%)          -2.567161e+00
# dtype: float64

# %%
adf_test(X['% Iron Feed'], '% Iron Feed')
print()
adf_test(X['% Silica Feed'], '% Silica Feed')
# Out:
# Results of Dickey-Fuller Test: % Iron Feed
# Test Statistic                   -3.815239
# p-value                           0.002755
# #Lags Used                       24.000000
# Number of Observations Used    3923.000000
# Critical Value (1%)              -3.432018
# Critical Value (5%)              -2.862277
# Critical Value (10%)             -2.567162
# dtype: float64
#
# Results of Dickey-Fuller Test: % Silica Feed
# Test Statistic                   -4.520901
# p-value                           0.000180
# #Lags Used                       27.000000
# Number of Observations Used    3920.000000
# Critical Value (1%)              -3.432019
# Critical Value (5%)              -2.862278
# Critical Value (10%)             -2.567163
# dtype: float64

# %%
adf_test(Y['% Iron Concentrate'], '% Iron Concentrate')
print()
adf_test(Y['% Silica Concentrate'], '% Silica Concentrate')
# Out:
# Results of Dickey-Fuller Test: % Iron Concentrate
# Test Statistic                -7.906544e+00
# p-value                        4.052341e-12
# #Lags Used                     2.400000e+01
# Number of Observations Used    3.923000e+03
# Critical Value (1%)           -3.432018e+00
# Critical Value (5%)           -2.862277e+00
# Critical Value (10%)          -2.567162e+00
# dtype: float64
#
# Results of Dickey-Fuller Test: % Silica Concentrate
# Test Statistic                -7.734785e+00
# p-value                        1.101028e-11
# #Lags Used                     2.400000e+01
# Number of Observations Used    3.923000e+03
# Critical Value (1%)           -3.432018e+00
# Critical Value (5%)           -2.862277e+00
# Critical Value (10%)          -2.567162e+00
# dtype: float64

# %%
for i in X.columns:
    mu, std = X.describe()[i][['mean','std']]
    X[i] = ( X[i] - mu ) / std
for i in Y.columns:
    mu, std = Y.describe()[i][['mean','std']]
    Y[i] = ( Y[i] - mu ) / std
# Out:
# C:\Users\DHRUV.DESKTOP-KRBVT38\AppData\Local\Temp\ipykernel_6908\608702555.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i] = ( Y[i] - mu ) / std
# C:\Users\DHRUV.DESKTOP-KRBVT38\AppData\Local\Temp\ipykernel_6908\608702555.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i] = ( Y[i] - mu ) / std

# %%
X.describe()
# Out:
#         % Iron Feed  % Silica Feed   Starch Flow    Amina Flow  Ore Pulp Flow  \
# count  3.948000e+03   3.948000e+03  3.948000e+03  3.948000e+03   3.948000e+03
# mean   1.094250e-15   1.727763e-16  2.591645e-16 -2.447665e-16   6.479113e-15
# std    1.000000e+00   1.000000e+00  1.000000e+00  1.000000e+00   1.000000e+00
# min   -2.576929e+00  -1.953884e+00 -2.287808e+00 -2.690200e+00  -2.158009e+00
# 25%   -6.901545e-01  -8.646252e-01 -6.278813e-01 -6.157294e-01  -3.437242e-01
# 50%   -5.358314e-02  -8.243504e-02  1.109486e-01  1.731994e-01   1.814838e-01
# 75%    6.690114e-01   7.799705e-01  7.261715e-01  7.282044e-01   5.589190e-01
# max    1.827457e+00   2.705138e+00  2.814717e+00  2.734392e+00   2.166409e+00
#
#         Ore Pulp pH  Ore Pulp Density  Flotation Column 01 Air Flow  \
# count  3.948000e+03      3.948000e+03                  3.948000e+03
# mean  -1.094250e-15      1.698967e-15                 -1.439803e-16
# std    1.000000e+00      1.000000e+00                  1.000000e+00
# min   -2.624841e+00     -2.322788e+00                 -3.559410e+00
# 25%   -6.253951e-01     -4.832673e-01                 -1.043736e+00
# 50%    7.786828e-02      2.485067e-01                  6.121076e-01
# 75%    6.980434e-01      6.833204e-01                  6.368589e-01
# max    2.681691e+00      2.524479e+00                  3.076801e+00
#
#        Flotation Column 02 Air Flow  Flotation Column 03 Air Flow
# 2017-09-09 23:00:00           -0.678528             -0.545228
#
# [3948 rows x 2 columns]

# %%
Y.describe()
# Out:
#        % Iron Concentrate  % Silica Concentrate
# count        3.948000e+03          3.948000e+03
# mean         2.750024e-15         -2.879606e-17
# std          1.000000e+00          1.000000e+00
# min         -2.672025e+00         -1.530930e+00
# 25%         -6.066898e-01         -7.849934e-01
# 50%          1.520964e-01         -2.910003e-01
# 75%          7.223085e-01          5.914366e-01
# max          2.679887e+00          2.847006e+00

# %%
y = pd.DataFrame([])
for i in Y.columns:
    y[i] = Y[i]-Y[i].shift(1)
y.dropna(inplace=True)

# determine appropriate lags using plot_pacf and plot_acf
from statsmodels.graphics.tsaplots import plot_pacf, plot_acf
for i in Y.columns:
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5))
    fig.suptitle(i)
    plot_pacf(y[i], lags=15, ax=ax1)
    plot_acf(y[i], lags=15, ax=ax2)
    plt.show()

y.head()
# Out:
#                      % Iron Concentrate  % Silica Concentrate
# date
# 2017-03-29 13:00:00            0.116736              0.062161
# 2017-03-29 14:00:00            0.062858             -0.088802
# 2017-03-29 15:00:00           -0.206534             -0.053281
# 2017-03-29 16:00:00           -2.496362              3.756322
# 2017-03-29 17:00:00            2.298808             -3.427755

# %%
x = pd.DataFrame([])
for i in X.columns:
    x[i] = X[i]-X[i].shift(1)
x.dropna(inplace=True)
# X = data[['x_var_1', 'x_var_2']]

# determine appropriate lags using plot_pacf and plot_acf
from statsmodels.graphics.tsaplots import plot_pacf, plot_acf
for i in X.columns:
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5))
    fig.suptitle(i)
    plot_pacf(x[i], lags=15, ax=ax1)
    plot_acf(x[i], lags=15, ax=ax2)
    plt.show()

x.head()
# Out:
#                      % Iron Feed  % Silica Feed  Starch Flow  Amina Flow  \
# date
# 2017-03-29 13:00:00     0.000000       0.000000     0.377608   -0.471772
# 2017-03-29 14:00:00     0.000000       0.000000    -0.301952    1.401537
# 2017-03-29 15:00:00     0.000000       0.000000    -1.363300    0.454363
# 2017-03-29 16:00:00    -0.122344       0.031941    -0.253753   -2.450542
# 2017-03-29 17:00:00     0.000000       0.000000     0.256284    1.843745
#
#                      Ore Pulp Flow  Ore Pulp pH  Ore Pulp Density  \
# date
# 2017-03-29 13:00:00      -0.339543    -0.279428         -1.821611
# 2017-03-29 14:00:00      -0.035774    -0.063696          1.025211
# 2017-03-29 15:00:00      -0.181934     0.357201          0.633224
# 2017-03-29 16:00:00      -0.070423     0.563840         -1.708399
# 2017-03-29 17:00:00      -0.462195    -1.088083          0.736582
#
#                      Flotation Column 01 Air Flow  \
# date
# 2017-03-29 13:00:00                     -0.007696
# 2017-03-29 14:00:00                     -0.021097
# 2017-03-29 15:00:00                      0.013874
# 2017-03-29 16:00:00                     -0.029671
# 2017-03-29 17:00:00                      0.012422
#
#                      Flotation Column 02 Air Flow  \
# date
# 2017-03-29 13:00:00                     -0.047952
# 2017-03-29 14:00:00                      0.104316
# 2017-03-29 15:00:00                     -0.198034
# 2017-03-29 16:00:00                     -0.298906
# 2017-03-29 17:00:00                      0.460313
#
#                      Flotation Column 03 Air Flow  ...  \
# date                                               ...
# 2017-03-29 13:00:00                      0.003627  ...
# 2017-03-29 14:00:00                     -0.117036  ...
# 2017-03-29 15:00:00                      0.023238  ...
# 2017-03-29 16:00:00                      0.069926  ...
# 2017-03-29 17:00:00                     -0.081897  ...
#
#                      Flotation Column 05 Air Flow  \
# date
# 2017-03-29 13:00:00                           0.0
# 2017-03-29 14:00:00                           0.0
# 2017-03-29 15:00:00                           0.0
# 2017-03-29 16:00:00                           0.0
# 2017-03-29 17:00:00                           0.0
#
#                      Flotation Column 06 Air Flow  \
# date
# 2017-03-29 13:00:00                     -0.013777
# 2017-03-29 14:00:00                      0.009004
# 2017-03-29 15:00:00                     -0.089737
# 2017-03-29 16:00:00                      0.090684
# 2017-03-29 17:00:00                     -0.007413
#
#                      Flotation Column 07 Air Flow  Flotation Column 01 Level  \
# date
# 2017-03-29 13:00:00                     -0.028893                   2.244580
# 2017-03-29 14:00:00                      0.010649                  -0.009554
# 2017-03-29 15:00:00                     -0.032159                   0.057090
# 2017-03-29 16:00:00                      0.041814                  -0.032605
# 2017-03-29 17:00:00                     -0.037483                  -0.032605
#
#                      Flotation Column 02 Level  Flotation Column 03 Level  \
# date
# 2017-03-29 13:00:00                   1.997815                   1.749067
# 2017-03-29 14:00:00                  -0.276063                   0.035896
# 2017-03-29 15:00:00                   0.031612                  -0.019675
# 2017-03-29 16:00:00                   0.031612                  -0.000403
# 2017-03-29 17:00:00                   0.031612                   0.016019
#
#                      Flotation Column 04 Level  Flotation Column 05 Level  \
# date
# 2017-03-29 13:00:00                   0.214230                   0.091842
# 2017-03-29 14:00:00                   0.258863                   0.410702
# 2017-03-29 15:00:00                  -0.365457                  -0.102272
# 2017-03-29 16:00:00                  -0.030801                  -0.147053
# 2017-03-29 17:00:00                   0.180122                   0.251772
#
#                      Flotation Column 06 Level  Flotation Column 07 Level
# date
# 2017-03-29 13:00:00                  -0.013266                  -0.618087
# 2017-03-29 14:00:00                   0.119241                   0.517497
# 2017-03-29 15:00:00                  -0.381368                   0.319877
# 2017-03-29 16:00:00                   0.326475                  -0.555076
# 2017-03-29 17:00:00                   0.002352                  -0.044821
#
# [5 rows x 21 columns]

# %% [markdown]
# `Model Training`

# %%
import tensorflow as tf
import keras
from keras.models import Sequential, Model
from keras.layers import Dense
from keras.layers import LSTM, Input, concatenate, Dropout
from keras.preprocessing.sequence import TimeseriesGenerator
from keras.regularizers import L2, L1
from sklearn.model_selection import train_test_split

# %%
Joined = pd.concat([X,Y], axis=1)
Joined.head()
TrainSet, TestSet = Joined.iloc[:int(len(Joined)*0.8),:], Joined.iloc[int(len(Joined)*0.8):,:]

# %%
Joined.shape
len(Joined)

print(TrainSet.shape)
print(TestSet.shape)
# Out:
# (3158, 23)
# (790, 23)

# %%
TrainSetX = TrainSet.drop(['% Iron Concentrate','% Silica Concentrate'], axis=1)
TrainSetY = TrainSet[['% Iron Concentrate','% Silica Concentrate']]

# %%
TestSetX = TestSet.drop(['% Iron Concentrate','% Silica Concentrate'], axis=1)
TestSetY = TestSet[['% Iron Concentrate','% Silica Concentrate']]

# %%
n_features = 2  # how many features to see
n_input = 8     # how many past rows to see for making prediction
batch_size = 32

trainGenerator = TimeseriesGenerator(TrainSetX.iloc[:,:2].values,  TrainSetY.values, length=n_input, batch_size=1)
print(len(trainGenerator))
print(trainGenerator[0])

testGenerator = TimeseriesGenerator(TestSetX.iloc[:,:2].values,  TestSetY.values, length=n_input, batch_size=1)
print(len(testGenerator))
print(testGenerator[0])
# Out:
# 3150
# (array([[[ 0.75694616, -0.78803955],
#         [ 0.75694616, -0.78803955],
#         [ 0.75694616, -0.78803955],
#         [ 0.75694616, -0.78803955],
#         [ 0.63460212, -0.75609861],
#         [ 0.63460212, -0.75609861],
#         [ 0.63460212, -0.75609861],
#         [ 0.63460212, -0.75609861]]]), array([[-0.80424364, -0.45642623]]))
# 782
# (array([[[-1.41657227,  1.53058267],
#         [-1.41657227,  1.53058267],
#         [-1.41657227,  1.53058267],
#         [-1.41657227,  1.53058267],
#         [-1.41657227,  1.53058267],
#         [-1.41657227,  1.53058267],
#         [-1.41657227,  1.53058267],
#         [-1.41657227,  1.53058267]]]), array([[ 1.30599021, -1.11356056]]))

# %%
def generator_to_array(generator):
    genX, genY = [], []
    for i in generator:
        xval, yval = i
        genX.extend(xval)
        genY.extend(yval)
    genX = np.array(genX)
    genY = np.array(genY)
    return genX, genY


xtrain, ytrain = generator_to_array(trainGenerator)
xtest, ytest = generator_to_array(testGenerator)

# %%
print("Train:")
print("x:", xtrain[0], "y:", ytrain[0])
print("\nTest:")
print("x:",xtest[0], "y:", ytest[0])
# Out:
# Train:
# x: [[ 0.75694616 -0.78803955]
#  [ 0.75694616 -0.78803955]
#  [ 0.75694616 -0.78803955]
#  [ 0.75694616 -0.78803955]
#  [ 0.63460212 -0.75609861]
#  [ 0.63460212 -0.75609861]
#  [ 0.63460212 -0.75609861]
#  [ 0.63460212 -0.75609861]] y: [-0.80424364 -0.45642623]
#
# Test:
# x: [[-1.41657227  1.53058267]
#  [-1.41657227  1.53058267]
#  [-1.41657227  1.53058267]
#  [-1.41657227  1.53058267]
#  [-1.41657227  1.53058267]
#  [-1.41657227  1.53058267]
#  [-1.41657227  1.53058267]
#  [-1.41657227  1.53058267]] y: [ 1.30599021 -1.11356056]

# %%
print(xtrain.shape)
print(ytrain.shape)
print(xtest.shape)
print(ytest.shape)
# Out:
# (3150, 8, 2)
# (3150, 2)
# (782, 8, 2)
# (782, 2)

# %%
numXTrain = TrainSet.iloc[n_input-1:-1, 2:-2].values
numXTest = TestSet.iloc[n_input-1:-1, 2:-2].values

# %%
print(numXTrain[0])
print(numXTest[0])
# Out:
# [-0.57547204 -0.30122183  1.02482156 -0.25134631 -0.67723759 -2.78644978
#  -2.74320833 -2.93894542 -1.81563023  1.94110505 -1.47728061 -1.39715453
#   2.54180346  2.29313946  2.2276587  -0.67590544  0.26108673  0.03466683
#   0.29178941]
# [-0.94609397  1.12731827 -2.03300616  1.61958855  1.06463771  0.64339911
#   0.67923713  0.61700046  2.03888105 -0.9467804  -1.47555425 -1.50754512
#  -0.00813589 -0.09827984  0.91637031 -1.30442789 -1.22608284 -0.4708702
#  -0.1726725 ]

# %%
TrainSet.iloc[7][:-2], TrainSet.iloc[8][-2:], xtrain[0][-1], ytrain[0], numXTrain[0]
# Out:
# (% Iron Feed                     0.634602
#  % Silica Feed                  -0.756099
#  Starch Flow                    -0.575472
#  Amina Flow                     -0.301222
#  Ore Pulp Flow                   1.024822
#  Ore Pulp pH                    -0.251346
#  Ore Pulp Density               -0.677238
#  Flotation Column 01 Air Flow   -2.786450
#  Flotation Column 02 Air Flow   -2.743208
#  Flotation Column 03 Air Flow   -2.938945
#  Flotation Column 04 Air Flow   -1.815630
#  Flotation Column 05 Air Flow    1.941105
#  Flotation Column 06 Air Flow   -1.477281
#  Flotation Column 07 Air Flow   -1.397155
#  Flotation Column 01 Level       2.541803
#  Flotation Column 02 Level       2.293139
#  Flotation Column 03 Level       2.227659
#  Flotation Column 04 Level      -0.675905
#  Flotation Column 05 Level       0.261087
#  Flotation Column 06 Level       0.034667
#  Flotation Column 07 Level       0.291789
#  Name: 2017-03-29 19:00:00, dtype: float64,
#  % Iron Concentrate     -0.804244
#  % Silica Concentrate   -0.456426
#  Name: 2017-03-29 20:00:00, dtype: float64,
#  array([ 0.63460212, -0.75609861]),
#  array([-0.80424364, -0.45642623]),
#  array([-0.57547204, -0.30122183,  1.02482156, -0.25134631, -0.67723759,
#         -2.78644978, -2.74320833, -2.93894542, -1.81563023,  1.94110505,
#         -1.47728061, -1.39715453,  2.54180346,  2.29313946,  2.2276587 ,
#         -0.67590544,  0.26108673,  0.03466683,  0.29178941]))

# %%
xtrain_ng, xtest_ng, ytrain_ng, ytest_ng = train_test_split(X,Y, random_state=0)

# %%
x = Sequential()
input_shape= 21
inputs = Input(shape=input_shape)

x = Dense(21, activation='leaky_relu')(inputs)
x = Dense(40, activation='leaky_relu', activity_regularizer=L2(0.003))(x)
x = Dropout(rate=0.7)(x)
x = Dense(20, activation='leaky_relu')(x)
x = Dropout(rate=0.4)(x)

x = Dense(20, activation='leaky_relu')(x)
x = Dropout(rate=0.5)(x)

x = Dense(20, activation='leaky_relu')(x)
x = Dropout(rate=0.4)(x)
x = Dense(20, activation='leaky_relu', activity_regularizer=L2(0.01))(x)
x = Dense(10, activation='leaky_relu')(x)

outputs = Dense(2)(x)
model = Model(inputs, outputs)
model.compile(optimizer='adam', loss='mse', metrics=['mse'])

model.summary()
# Out:
# Model: "model_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 21)]              0
#
#  dense_34 (Dense)            (None, 21)                462
#
#  dense_35 (Dense)            (None, 40)                880
#
#  dropout_14 (Dropout)        (None, 40)                0
#
#  dense_36 (Dense)            (None, 20)                820
#
#  dropout_15 (Dropout)        (None, 20)                0
#
#  dense_37 (Dense)            (None, 20)                420
#
#  dropout_16 (Dropout)        (None, 20)                0
#
#  dense_38 (Dense)            (None, 20)                420
#
#  dropout_17 (Dropout)        (None, 20)                0
#
#  dense_39 (Dense)            (None, 20)                420
#
#  dense_40 (Dense)            (None, 10)                210
#
#  dense_41 (Dense)            (None, 2)                 22
#
# =================================================================
# Total params: 3,654
# Trainable params: 3,654
# Non-trainable params: 0
# _________________________________________________________________

# %%
import os
for dirname, _, filenames in os.walk('C://Users//DHRUV.DESKTOP-KRBVT38//OneDrive//Desktop//Work//Project//data science//Kaggle//ntcc intern project//Project10_Quality Prediction in a Mining Process//Project10//Project10_Quality Prediction in a Mining Process//MiningProcess_Flotation_Plant_Database.csv'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
checkpoint_filepath = 'C://Users//DHRUV.DESKTOP-KRBVT38//OneDrive//Desktop//Work//Project//data science//Kaggle//ntcc intern project//Project10_Quality Prediction in a Mining Process//Project10//Project10_Quality Prediction in a Mining Process//checkpoint//ModelA'
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=True,
    monitor='val_mse',
    mode='min',
    save_best_only=True)

# %%
hist = model.fit(xtrain_ng, ytrain_ng, batch_size=32, validation_split=0.3, epochs=100, verbose=1, callbacks=[model_checkpoint_callback,])
# Out:
# Epoch 1/100
# 65/65 [==============================] - 3s 10ms/step - loss: 1.0930 - mse: 1.0512 - val_loss: 0.9643 - val_mse: 0.9517
# Epoch 2/100
# 65/65 [==============================] - 0s 5ms/step - loss: 1.0449 - mse: 1.0212 - val_loss: 0.9619 - val_mse: 0.9521
# Epoch 3/100
# 65/65 [==============================] - 0s 4ms/step - loss: 1.0348 - mse: 1.0185 - val_loss: 0.9607 - val_mse: 0.9527
# Epoch 4/100
# 65/65 [==============================] - 0s 3ms/step - loss: 1.0232 - mse: 1.0111 - val_loss: 0.9595 - val_mse: 0.9526
# Epoch 5/100
# 65/65 [==============================] - 0s 6ms/step - loss: 1.0180 - mse: 1.0072 - val_loss: 0.9575 - val_mse: 0.9513
# Epoch 6/100
# 65/65 [==============================] - 0s 5ms/step - loss: 1.0081 - mse: 0.9982 - val_loss: 0.9473 - val_mse: 0.9417
# Epoch 7/100
# 65/65 [==============================] - 0s 6ms/step - loss: 1.0094 - mse: 0.9995 - val_loss: 0.9379 - val_mse: 0.9327
# Epoch 8/100
# 65/65 [==============================] - 0s 6ms/step - loss: 1.0019 - mse: 0.9928 - val_loss: 0.9297 - val_mse: 0.9249
# Epoch 9/100
# 65/65 [==============================] - 0s 5ms/step - loss: 0.9945 - mse: 0.9857 - val_loss: 0.9210 - val_mse: 0.9164
# Epoch 10/100
# 65/65 [==============================] - 0s 6ms/step - loss: 0.9740 - mse: 0.9652 - val_loss: 0.9015 - val_mse: 0.8968
# Epoch 11/100
# 65/65 [==============================] - 0s 5ms/step - loss: 0.9501 - mse: 0.9401 - val_loss: 0.8813 - val_mse: 0.8764
# Epoch 12/100
# 65/65 [==============================] - 0s 4ms/step - loss: 0.9420 - mse: 0.9312 - val_loss: 0.8713 - val_mse: 0.8664
# Epoch 13/100
# 65/65 [==============================] - 0s 3ms/step - loss: 0.9569 - mse: 0.9474 - val_loss: 0.8725 - val_mse: 0.8679
# Epoch 14/100
# 65/65 [==============================] - 0s 4ms/step - loss: 0.9362 - mse: 0.9263 - val_loss: 0.8719 - val_mse: 0.8676
# Epoch 15/100
# 65/65 [==============================] - 0s 4ms/step - loss: 0.9391 - mse: 0.9294 - val_loss: 0.8724 - val_mse: 0.8682
# Epoch 16/100
# 65/65 [==============================] - 0s 5ms/step - loss: 0.9165 - mse: 0.9061 - val_loss: 0.8565 - val_mse: 0.8520
# Epoch 17/100
# 65/65 [==============================] - 0s 6ms/step - loss: 0.9049 - mse: 0.8939 - val_loss: 0.8528 - val_mse: 0.8483
# Epoch 18/100
# 65/65 [==============================] - 0s 7ms/step - loss: 0.9058 - mse: 0.8953 - val_loss: 0.8505 - val_mse: 0.8460
# Epoch 19/100
# 65/65 [==============================] - 0s 4ms/step - loss: 0.9120 - mse: 0.9017 - val_loss: 0.8542 - val_mse: 0.8498
# Epoch 20/100
# 65/65 [==============================] - 0s 5ms/step - loss: 0.8939 - mse: 0.8840 - val_loss: 0.8390 - val_mse: 0.8343
# Epoch 21/100
# 65/65 [==============================] - 0s 5ms/step - loss: 0.8964 - mse: 0.8857 - val_loss: 0.8346 - val_mse: 0.8298
# Epoch 22/100
# 65/65 [==============================] - 0s 4ms/step - loss: 0.8848 - mse: 0.8753 - val_loss: 0.8375 - val_mse: 0.8328
# Epoch 23/100
# 65/65 [==============================] - 0s 5ms/step - loss: 0.8766 - mse: 0.8653 - val_loss: 0.8273 - val_mse: 0.8224
# Epoch 24/100
# 65/65 [==============================] - 0s 5ms/step - loss: 0.8657 - mse: 0.8558 - val_loss: 0.8254 - val_mse: 0.8206
# Epoch 25/100
# 65/65 [==============================] - 0s 5ms/step - loss: 0
100
# 65/65 [==============================] - 0s 3ms/step - loss: 0.7462 - mse: 0.7385 - val_loss: 0.8228 - val_mse: 0.8182
# Epoch 93/100
# 65/65 [==============================] - 0s 3ms/step - loss: 0.7346 - mse: 0.7274 - val_loss: 0.8243 - val_mse: 0.8199
# Epoch 94/100
# 65/65 [==============================] - 0s 3ms/step - loss: 0.7350 - mse: 0.7286 - val_loss: 0.8247 - val_mse: 0.8203
# Epoch 95/100
# 65/65 [==============================] - 0s 3ms/step - loss: 0.7523 - mse: 0.7458 - val_loss: 0.8338 - val_mse: 0.8292
# Epoch 96/100
# 65/65 [==============================] - 0s 4ms/step - loss: 0.7288 - mse: 0.7222 - val_loss: 0.8323 - val_mse: 0.8274
# Epoch 97/100
# 65/65 [==============================] - 0s 3ms/step - loss: 0.7455 - mse: 0.7383 - val_loss: 0.8313 - val_mse: 0.8264
# Epoch 98/100
# 65/65 [==============================] - 0s 4ms/step - loss: 0.7452 - mse: 0.7382 - val_loss: 0.8280 - val_mse: 0.8235
# Epoch 99/100
# 65/65 [==============================] - 0s 3ms/step - loss: 0.7364 - mse: 0.7300 - val_loss: 0.8242 - val_mse: 0.8198
# Epoch 100/100
# 65/65 [==============================] - 0s 3ms/step - loss: 0.7453 - mse: 0.7391 - val_loss: 0.8265 - val_mse: 0.8219

# %%
model.load_weights(checkpoint_filepath)

# %%
hist.history.keys()
# Out:
# dict_keys(['loss', 'mse', 'val_loss', 'val_mse'])

# %%
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.legend(['train', 'valid'])

# %%
plt.plot(hist.history['mse'][0:])
plt.plot(hist.history['val_mse'][0:])
plt.legend(['train', 'valid'])

# %%
ypred = model.predict(xtest_ng, verbose=0)

# %%
from sklearn.metrics import mean_squared_error as mse, r2_score as r2
print(mse(ytest_ng, ypred))
print(mse(ytest_ng, ypred)**0.5)
print(r2(ytest_ng, ypred))
# Out:
# 0.8588795402347158
# 0.9267575412343381
# 0.15072747670716818

# %%
plt.show()
plt.plot(ytest[:100])
plt.plot(ypred[:100])
plt.figlegend(["test","pred"])

# %%
n_features = 21

# %%
xtrain[:int( len(xtrain)*0.8)].shape, ytrain[:int( len(xtrain)*0.8)].shape, numXTrain[:int( len(xtrain)*0.8)].shape
# Out:
# ((2520, 8, 2), (2520, 2), (2520, 19))

# %%
valid = ([xtrain[int( len(xtrain)*0.8):], numXTrain[int( len(xtrain)*0.8):]], ytrain[int( len(xtrain)*0.8):])

# %%
from tensorflow.keras.layers import Input, LSTM, Dense, concatenate, Flatten
from tensorflow.keras.models import Model

# Define the input shapes
ts_input_shape = (8, 2)
num_input_shape = (19,)

# Define the time series input layer
ts_input_layer = Input(shape=ts_input_shape, name='ts_input')

# Define the LSTM layer for the time series input
lstm_output = LSTM(units=100, activation='relu', return_sequences=True)(ts_input_layer)
lstm_output_flat = Flatten()(lstm_output)

# Define the time series input layer
num_input_layer = Input(shape=num_input_shape, name='num_input')

# Concatenate the LSTM output and the numerical input
concatenated_inputs = concatenate([lstm_output_flat, num_input_layer], axis=-1)

# Apply a series of dense layers to the concatenated inputs
dense_output = Dense(units=120, activation='leaky_relu', kernel_regularizer=L2(0.001))(concatenated_inputs)
dense_output = Dense(units=100, activation='leaky_relu', kernel_regularizer=L2(0.01))(dense_output)
dense_output = Dense(units=100, activation='leaky_relu', kernel_regularizer=L2(0.01))(dense_output)
dense_output = Dropout(rate=0.5)(dense_output)

dense_output = Dense(units=50, activation='leaky_relu', kernel_regularizer=L2(0.01))(dense_output)
dense_output = Dense(units=50, activation='leaky_relu', kernel_regularizer=L2(0.01))(dense_output)
dense_output = Dropout(rate=0.5)(dense_output)

dense_output = Dense(units=30, activation='leaky_relu', kernel_regularizer=L2(0.01))(dense_output)
dense_output = Dense(units=30, activation='leaky_relu', kernel_regularizer=L2(0.01))(dense_output)
dense_output = Dropout(rate=0.5)(dense_output)

dense_output = Dense(units=30, activation='leaky_relu', kernel_regularizer=L2(0.01))(dense_output)

# Define the output layer
output_layer = Dense(units=2, activation='leaky_relu')(dense_output)

# Define the model with both inputs and the output
model = Model(inputs=[ts_input_layer, num_input_layer], outputs=output_layer)

# Compile the model
model.compile(optimizer='adam', loss='mse', metrics='mse')

# Print the model summary
model.summary()
# Out:
# Model: "model_5"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  ts_input (InputLayer)          [(None, 8, 2)]       0           []
#
#  lstm_2 (LSTM)                  (None, 8, 100)       41200       ['ts_input[0][0]']
#
#  flatten_2 (Flatten)            (None, 800)          0           ['lstm_2[0][0]']
#
#  num_input (InputLayer)         [(None, 19)]         0           []
#
#  concatenate_2 (Concatenate)    (None, 819)          0           ['flatten_2[0][0]',
#                                                                   'num_input[0][0]']
#
#  dense_42 (Dense)               (None, 120)          98400       ['concatenate_2[0][0]']
#
#  dense_43 (Dense)               (None, 100)          12100       ['dense_42[0][0]']
#
#  dense_44 (Dense)               (None, 100)          10100       ['dense_43[0][0]']
#
#  dropout_18 (Dropout)           (None, 100)          0           ['dense_44[0][0]']
#
#  dense_45 (Dense)               (None, 50)           5050        ['dropout_18[0][0]']
#
#  dense_46 (Dense)               (None, 50)           2550        ['dense_45[0][0]']
#
#  dropout_19 (Dropout)           (None, 50)           0           ['dense_46[0][0]']
#
#  dense_47 (Dense)               (None, 30)           1530        ['dropout_19[0][0]']
#
#  dense_48 (Dense)               (None, 30)           930         ['dense_47[0][0]']
#
#  dropout_20 (Dropout)           (None, 30)           0           ['dense_48[0][0]']
#
#  dense_49 (Dense)               (None, 30)           930         ['dropout_20[0][0]']
#
#  dense_50 (Dense)               (None, 2)            62          ['dense_49[0][0]']
#
# ==================================================================================================
# Total params: 172,852
# Trainable params: 172,852
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
hist = model.fit([xtrain[:int( len(xtrain)*0.8)], numXTrain[:int( len(xtrain)*0.8)]], ytrain[:int( len(xtrain)*0.8)], validation_data=valid, epochs=100, verbose=2)
# Out:
# Epoch 1/100
# 79/79 - 4s - loss: 3.6043 - mse: 1.0097 - val_loss: 2.1424 - val_mse: 0.8536 - 4s/epoch - 54ms/step
# Epoch 2/100
# 79/79 - 1s - loss: 1.7427 - mse: 0.9936 - val_loss: 1.2530 - val_mse: 0.8619 - 876ms/epoch - 11ms/step
# Epoch 3/100
# 79/79 - 1s - loss: 1.2119 - mse: 0.9615 - val_loss: 1.0434 - val_mse: 0.8871 - 1s/epoch - 13ms/step
# Epoch 4/100
# 79/79 - 1s - loss: 1.0527 - mse: 0.9358 - val_loss: 1.0061 - val_mse: 0.9157 - 1s/epoch - 14ms/step
# Epoch 5/100
# 79/79 - 1s - loss: 1.0057 - mse: 0.9287 - val_loss: 0.9701 - val_mse: 0.9022 - 973ms/epoch - 12ms/step
# Epoch 6/100
# 79/79 - 1s - loss: 0.9795 - mse: 0.9152 - val_loss: 0.9583 - val_mse: 0.8993 - 886ms/epoch - 11ms/step
# Epoch 7/100
# 79/79 - 1s - loss: 0.9806 - mse: 0.9221 - val_loss: 0.9921 - val_mse: 0.9319 - 1s/epoch - 13ms/step
# Epoch 8/100
# 79/79 - 1s - loss: 0.9737 - mse: 0.9177 - val_loss: 0.9372 - val_mse: 0.8807 - 1s/epoch - 13ms/step
# Epoch 9/100
# 79/79 - 1s - loss: 0.9688 - mse: 0.9089 - val_loss: 0.9518 - val_mse: 0.8946 - 764ms/epoch - 10ms/step
# Epoch 10/100
# 79/79 - 1s - loss: 0.9553 - mse: 0.8949 - val_loss: 0.9868 - val_mse: 0.9233 - 754ms/epoch - 10ms/step
# Epoch 11/100
# 79/79 - 1s - loss: 0.9460 - mse: 0.8864 - val_loss: 0.9721 - val_mse: 0.9108 - 730ms/epoch - 9ms/step
# Epoch 12/100
# 79/79 - 1s - loss: 0.9467 - mse: 0.8848 - val_loss: 0.9806 - val_mse: 0.9181 - 754ms/epoch - 10ms/step
# Epoch 13/100
# 79/79 - 1s - loss: 0.9379 - mse: 0.8735 - val_loss: 0.9925 - val_mse: 0.9306 - 758ms/epoch - 10ms/step
# Epoch 14/100
# 79/79 - 1s - loss: 0.9448 - mse: 0.8819 - val_loss: 0.9565 - val_mse: 0.8970 - 767ms/epoch - 10ms/step
# Epoch 15/100
# 79/79 - 1s - loss: 0.9413 - mse: 0.8773 - val_loss: 0.9752 - val_mse: 0.9118 - 759ms/epoch - 10ms/step
# Epoch 16/100
# 79/79 - 1s - loss: 0.9396 - mse: 0.8747 - val_loss: 0.9945 - val_mse: 0.9278 - 796ms/epoch - 10ms/step
# Epoch 17/100
# 79/79 - 1s - loss: 0.9413 - mse: 0.8756 - val_loss: 1.0237 - val_mse: 0.9607 - 731ms/epoch - 9ms/step
# Epoch 18/100
# 79/79 - 1s - loss: 0.9302 - mse: 0.8615 - val_loss: 0.9882 - val_mse: 0.9215 - 739ms/epoch - 9ms/step
# Epoch 19/100
# 79/79 - 1s - loss: 0.9335 - mse: 0.8671 - val_loss: 1.0614 - val_mse: 0.9896 - 754ms/epoch - 10ms/step
# Epoch 20/100
# 79/79 - 1s - loss: 0.9321 - mse: 0.8624 - val_loss: 1.0340 - val_mse: 0.9650 - 742ms/epoch - 9ms/step
# Epoch 21/100
# 79/79 - 1s - loss: 0.9292 - mse: 0.8613 - val_loss: 1.0069 - val_mse: 0.9385 - 764ms/epoch - 10ms/step
# Epoch 22/100
# 79/79 - 1s - loss: 0.9283 - mse: 0.8589 - val_loss: 0.9984 - val_mse: 0.9334 - 756ms/epoch - 10ms/step
# Epoch 23/100
# 79/79 - 1s - loss: 0.9259 - mse: 0.8554 - val_loss: 0.9953 - val_mse: 0.9247 - 731ms/epoch - 9ms/step
# Epoch 24/100
# 79/79 - 1s - loss: 0.9255 - mse: 0.8530 - val_loss: 1.0002 - val_mse: 0.9292 - 746ms/epoch - 9ms/step
# Epoch 25/100
# 79/79 - 1s - loss: 0.9144 - mse: 0.8419 - val_loss: 1.0008 - val_mse: 0.9252 - 746ms/epoch - 9ms/step
# Epoch 26/100
# 79/79 - 1s - loss: 0.9177 - mse: 0.8422 - val_loss: 1.0803 - val_mse: 1.0058 - 727ms/epoch - 9ms/step
# Epoch 27/100
# 79/79 - 1s - loss: 0.9202 - mse: 0.8444 - val_loss: 1.0191 - val_mse: 0.9421 - 751ms/epoch - 10ms/step
# Epoch 28/100
# 79/79 - 1s - loss: 0.9070 - mse: 0.8317 - val_loss: 1.0362 - val_mse: 0.9581 - 746ms/epoch - 9ms/step
# Epoch 29/100
# 79/79 - 1s - loss: 0.9108 - mse: 0.8349 - val_loss: 1.0193 - val_mse: 0.9425 - 755ms/epoch - 10ms/step
# Epoch 30/100
# 79/79 - 1s - loss: 0.9298 - mse: 0.8522 - val_loss: 0.9826 - val_mse: 0.9047 - 736ms/epoch - 9ms/step
# Epoch 31/100
# 79/79 - 1s - loss: 0.9016 - mse: 0.8228 - val_loss: 1.0049 - val_mse: 0.9275 - 735ms/epoch - 9ms/step
# Epoch 32/100
# 79/79 - 1s - loss: 0.9101 - mse: 0.8295 - val_loss: 1.0136 - val_mse: 0.9268 - 734ms/epoch - 9ms/step
# Epoch 33/100
# 79/79 - 1s - loss: 0.8997 - mse: 0.8169 - val_loss: 1.0118 - val_mse: 0.9287 - 729ms/epoch - 9ms/step
# Epoch 34/100
# 79/79 - 1s - loss: 0.9023 - mse: 0.8200 - val_loss: 1.0525 - val_mse: 0.9694 - 729ms/epoch - 9ms/step
# Epoch 35/100
# 79/79 - 1s - loss: 0.8968 - mse: 0.8152 - val_loss: 1.0389 - val_mse: 0.9575 - 753ms/epoch - 10ms/step
# Epoch 36/100
# 79/79 - 1s - loss: 0.8964 - mse: 0.8145 - val_loss: 1.0366 - val_mse: 0.9554 - 744ms/epoch - 9ms/step
# Epoch 37/100
# 79/79 - 1s - loss: 0.8928 - mse: 0.8100 - val_loss: 0.9997 - val_mse: 0.9196 - 729ms/epoch - 9ms/step
# Epoch 38/100
# 79/79 - 1s - loss: 0.8818 - mse: 0.7986 - val_loss: 1.0248 - val_mse: 0.9402 - 737ms/epoch - 9ms/step
# Epoch 39/100
# 79/79 - 1s - loss: 0.8926 - mse: 0.8084 - val_loss: 1.0764 - val_mse: 0.9915 - 736ms/epoch - 9ms/step
# Epoch 40/100
# 79/79 - 1s - loss: 0.8985 - mse: 0.8135 - val_loss: 1.0346 - val_mse: 0.9501 - 733ms/epoch - 9ms/step
# Epoch 41/100
# 79/79 - 1s - loss: 0.8914 - mse: 0.8062 - val_loss: 1.0701 - val_mse: 0.9872 - 795ms/epoch - 10ms/step
# Epoch 42/100
# 79/79 - 1s - loss: 0.8898 - mse: 0.8049 - val_loss: 1.0675 - val_mse: 0.9840 - 802ms/epoch - 10ms/step
# Epoch 43/100
# 79/79 - 1s - loss: 0.8839 - mse: 0.8003 - val_loss: 1.0814 - val_mse: 0.9974 - 775ms/epoch - 10ms/step
# Epoch 44/100
# 79/79 - 1s - loss: 0.8759 - mse: 0.7909 - val_loss: 1.0441 - val_mse: 0.9617 - 798ms/epoch - 10ms/step
# Epoch 45/100
# 79/79 - 1s - loss: 0.8756 - mse: 0.7890 - val_loss: 1.0791 - val_mse: 0.9941 - 783ms/epoch - 10ms/step
# Epoch 46/100
# 79/79 - 1s - loss: 0.8692 - mse: 0.7851 - val_loss: 1.1690 - val_mse: 1.0831 - 795ms/epoch - 10ms/step
# Epoch 47/100
# 79/79 - 1s - loss: 0.8753 - mse: 0.7913 - val_loss: 1.0558 - val_mse: 0.9720 - 788ms/epoch - 10ms/step
# Epoch 48/100
# 79/79 - 1s - loss: 0.8666 - mse: 0.7810 - val_loss: 1.0925 - val_mse: 1.0081 - 786ms/epoch - 10ms/step
# Epoch 49/100
# 79/79 - 1s - loss: 0.8785 - mse: 0.7924 - val_loss: 1.0266 - val_mse: 0.9400 - 790ms/epoch - 10ms/step
# Epoch 50/100
# 79/79 - 1s - loss: 0.8779 - mse: 0.7922 - val_loss: 1.0684 - val_mse: 0.9854 - 782ms/epoch - 10ms/step
# Epoch 51/100
# 79/79 - 1s - loss: 0.8733 - mse: 0.7861 - val_loss: 1.0693 - val_mse: 0.9876 - 785ms/epoch - 10ms/step
# Epoch 52/100
# 79/79 - 1s - loss: 0.8657 - mse: 0.7777 - val_loss: 1.0845 - val_mse: 0.9976 - 778ms/epoch - 10ms/step
# Epoch 53/100
# 79/79 - 1s - loss: 0.8643 - mse: 0.7771 - val_loss: 1.0979 - val_mse: 1.0082 - 785ms/epoch - 10ms/step
# Epoch 54/100
# 79/79 - 1s - loss: 0.8676 - mse: 0.7791 - val_loss: 1.0729 - val_mse: 0.9865 - 817ms/epoch - 10ms/step
# Epoch 55/100
# 79/79 - 1s - loss: 0.8632 - mse: 0.7764 - val_loss: 1.1735 - val_mse: 1.0807 - 808ms/epoch - 10ms/step
# Epoch 56/100
# 79/79 - 1s - loss: 0.8804 - mse: 0.7946 - val_loss: 1.0746 - val_mse: 0.9897 - 793ms/epoch - 10ms/step
# Epoch 57/100
# 79/79 - 1s - loss: 0.8614 - mse: 0.7739 - val_loss: 1.1812 - val_mse: 1.0936 - 788ms/epoch - 10ms/step
# Epoch 58/100
# 79/79 - 1s - loss: 0.8584 - mse: 0.7722 - val_loss: 1.1308 - val_mse: 1.0430 - 779ms/epoch - 10ms/step
# Epoch 59/100
# 79/79 - 1s - loss: 0.8629 - mse: 0.7743 - val_loss: 1.1429 - val_mse: 1.0541 - 773ms/epoch - 10ms/step
# Epoch 60/100
# 79/79 - 1s - loss: 0.8581 - mse: 0.7690 - val_loss: 1.0375 - val_mse: 0.9550 - 799ms/epoch - 10ms/step
# Epoch 61/100
# 79/79 - 1s - loss: 0.8726 - mse: 0.7825 - val_loss: 1.1361 - val_mse: 1.0436 - 797ms/epoch - 10ms/step
# Epoch 62/100
# 79/79 - 1s - loss: 0.8504 - mse: 0.7607 - val_loss: 1.1049 - val_mse: 1.0166 - 796ms/epoch - 10ms/step
# Epoch 63/100
# 79/79 - 1s - loss: 0.8554 - mse: 0.7658 - val_loss: 1.1270 - val_mse: 1.0338 - 778ms/epoch - 10ms/step
# Epoch 64/100
# 79/79 - 1s - loss: 0.8557 - mse: 0.7626 - val_loss: 1.0890 - val_mse: 0.9964 - 780ms/epoch - 10ms/step
# Epoch 65/100
# 79/79 - 1s - loss: 0.8496 - mse: 0.7577 - val_loss: 1.0644 - val_mse: 0.9727 - 926ms/epoch - 12ms/step
# Epoch 66/100
# 79/79 - 1s - loss: 0.8433 - mse: 0.7504 - val_loss: 1.0588 - val_mse: 0.9686 - 850ms/epoch - 11ms/step
# Epoch 67/100
# 79/79 - 1s - loss: 0.8475 - mse: 0.7563 - val_loss: 1.0507 - val_mse: 0.9591 - 806ms/epoch - 10ms/step
# Epoch 68/100
# 79/79 - 1s - loss: 0.8581 - mse: 0.7669 - val_loss: 1.0678 - val_mse: 0.9774 - 778ms/epoch - 10ms/step
# Epoch 69/100
# 79/79 - 1s - loss: 0.8400 - mse: 0.7485 - val_loss: 1.0910 - val_mse: 1.0022 - 764ms/epoch - 10ms/step
# Epoch 70/100
# 79/79 - 1s - loss: 0.8309 - mse: 0.7402 - val_loss: 1.0793 - val_mse: 0.9885 - 787ms/epoch - 10ms/step
# Epoch 71/100
# 79/79 - 1s - loss: 0.8431 - mse: 0.7506 - val_loss: 1.0786 - val_mse: 0.9842 - 783ms/epoch - 10ms/step
# Epoch 72/100
# 79/79 - 1s - loss: 0.8378 - mse: 0.7441 - val_loss: 1.0600 - val_mse: 0.9702 - 812ms/epoch - 10ms/step
# Epoch 73/100
# 79/79 - 1s - loss: 0.8542 - mse: 0.7606 - val_loss: 1.0826 - val_mse: 0.9866 - 1s/epoch - 15ms/step
# Epoch 74/100
# 79/79 - 1s - loss: 0.8460 - mse: 0.7501 - val_loss: 1.0692 - val_mse: 0.9738 - 1s/epoch - 15ms/step
# Epoch 75/100
# 79/79 - 1s - loss: 0.8332 - mse: 0.7366 - val_loss: 1.0652 - val_mse: 0.9696 - 1s/epoch - 15ms/step
# Epoch 76/100
# 79/79 - 2s - loss: 0.8341 - mse: 0.7381 - val_loss: 1.1629 - val_mse: 1.0629 - 2s/epoch - 19ms/step
# Epoch 77/100
# 79/79 - 1s - loss: 0.8427 - mse: 0.7432 - val_loss: 1.0884 - val_mse: 0.9889 - 1s/epoch - 18ms/step
# Epoch 78/100
# 79/79 - 1s - loss: 0.8167 - mse: 0.7185 - val_loss: 1.1672 - val_mse: 1.0713 - 1s/epoch - 14ms/step
# Epoch 79/100
# 79/79 - 1s - loss: 0.8248 - mse: 0.7292 - val_loss: 1.1415 - val_mse: 1.0450 - 1s/epoch - 14ms/step
# Epoch 80/100
# 79/79 - 1s - loss: 0.8305 - mse: 0.7341 - val_loss: 1.1394 - val_mse: 1.0420 - 920ms/epoch - 12ms/step
# Epoch 81/100
# 79/79 - 1s - loss: 0.8165 - mse: 0.7177 - val_loss: 1.1343 - val_mse: 1.0372 - 628ms/epoch - 8ms/step
# Epoch 82/100
# 79/79 - 1s - loss: 0.8234 - mse: 0.7253 - val_loss: 1.0653 - val_mse: 0.9673 - 613ms/epoch - 8ms/step
# Epoch 83/100
# 79/79 - 1s - loss: 0.8160 - mse: 0.7176 - val_loss: 1.1602 - val_mse: 1.0590 - 711ms/epoch - 9ms/step
# Epoch 84/100
# 79/79 - 1s - loss: 0.8079 - mse: 0.7080 - val_loss: 1.1828 - val_mse: 1.0832 - 880ms/epoch - 11ms/step
# Epoch 85/100
# 79/79 - 1s - loss: 0.8194 - mse: 0.7217 - val_loss: 1.1315 - val_mse: 1.0326 - 799ms/epoch - 10ms/step
# Epoch 86/100
# 79/79 - 1s - loss: 0.8039 - mse: 0.7040 - val_loss: 1.0823 - val_mse: 0.9861 - 813ms/epoch - 10ms/step
# Epoch 87/100
# 79/79 - 1s - loss: 0.8186 - mse: 0.7191 - val_loss: 1.1352 - val_mse: 1.0329 - 818ms/epoch - 10ms/step
# Epoch 88/100
# 79/79 - 1s - loss: 0.8228 - mse: 0.7217 - val_loss: 1.1228 - val_mse: 1.0230 - 824ms/epoch - 10ms/step
# Epoch 89/100
# 79/79 - 1s - loss: 0.8176 - mse: 0.7166 - val_loss: 1.2035 - val_mse: 1.1028 - 816ms/epoch - 10ms/step
# Epoch 90/100
# 79/79 - 1s - loss: 0.8124 - mse: 0.7114 - val_loss: 1.1218 - val_mse: 1.0223 - 775ms/epoch - 10ms/step
# Epoch 91/100
# 79/79 - 1s - loss: 0.8114 - mse: 0.7106 - val_loss: 1.1963 - val_mse: 1.0948 - 802ms/epoch - 10ms/step
# Epoch 92/100
# 79/79 - 1s - loss: 0.8111 - mse: 0.7105 - val_loss: 1.1435 - val_mse: 1.0416 - 808ms/epoch - 10ms/step
# Epoch 93/100
# 79/79 - 1s - loss: 0.8172 - mse: 0.7159 - val_loss: 1.1896 - val_mse: 1.0848 - 798ms/epoch - 10ms/step
# Epoch 94/100
# 79/79 - 1s - loss: 0.8082 - mse: 0.7046 - val_loss: 1.1920 - val_mse: 1.0844 - 804ms/epoch - 10ms/step
# Epoch 95/100
# 79/79 - 1s - loss: 0.8014 - mse: 0.6982 - val_loss: 1.1285 - val_mse: 1.0267 - 802ms/epoch - 10ms/step
# Epoch 96/100
# 79/79 - 1s - loss: 0.8133 - mse: 0.7107 - val_loss: 1.1448 - val_mse: 1.0424 - 792ms/epoch - 10ms/step
# Epoch 97/100
# 79/79 - 1s - loss: 0.8083 - mse: 0.7051 - val_loss: 1.1585 - val_mse: 1.0542 - 790ms/epoch - 10ms/step
# Epoch 98/100
# 79/79 - 1s - loss: 0.7904 - mse: 0.6873 - val_loss: 1.1369 - val_mse: 1.0345 - 789ms/epoch - 10ms/step
# Epoch 99/100
# 79/79 - 1s - loss: 0.7925 - mse: 0.6893 - val_loss: 1.1698 - val_mse: 1.0663 - 790ms/epoch - 10ms/step
# Epoch 100/100
# 79/79 - 1s - loss: 0.8050 - mse: 0.7016 - val_loss: 1.0972 - val_mse: 0.9936 - 793ms/epoch - 10ms/step

# %%
model.load_weights(checkpoint_filepath)
# Out:
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.core.dense.Dense object at 0x000002BD06AF1630> and <keras.layers.reshaping.flatten.Flatten object at 0x000002BD06B87460>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.core.dense.Dense object at 0x000002BD06AF2980> and <keras.layers.merging.concatenate.Concatenate object at 0x000002BD06B87D90>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.core.dense.Dense object at 0x000002BD06AABDF0> and <keras.layers.core.dense.Dense object at 0x000002BD06AF2980>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.core.dense.Dense object at 0x000002BD06AA80D0> and <keras.layers.regularization.dropout.Dropout object at 0x000002BD06AF0700>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.core.dense.Dense object at 0x000002BD06AAABF0> and <keras.layers.regularization.dropout.Dropout object at 0x000002BD06AA9C90>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.layers.core.dense.Dense object at 0x000002BD06AABF10> and <keras.layers.core.dense.Dense object at 0x000002BD06AAABF0>).
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[213], line 1
# ----> 1 model.load_weights(checkpoint_filepath)
#
# File D:\lib\site-packages\keras\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File D:\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:720, in BaseResourceVariable._restore_from_tensors(self, restored_tensors)
#     717   assigned_variable = shape_safe_assign_variable_handle(
#     718       self.handle, self.shape, restored_tensor)
#     719 except ValueError as e:
# --> 720   raise ValueError(
#     721       f"Received incompatible tensor with shape {restored_tensor.shape} "
#     722       f"when attempting to restore variable with shape {self.shape} "
#     723       f"and name {self.name}.") from e
#     724 return assigned_variable
#
# ValueError: Received incompatible tensor with shape (40,) when attempting to restore variable with shape (120,) and name dense_42/bias:0.

# %%
hist.history.keys()
# Out:
# dict_keys(['loss', 'mse', 'val_loss', 'val_mse'])

# %%
plt.plot(hist.history['loss'][1:])
plt.plot(hist.history['val_loss'][1:])
plt.legend(['train', 'valid'])

# %%
plt.plot(hist.history['mse'])
plt.plot(hist.history['val_mse'])
plt.legend(['train', 'valid'])

# %%
ypred = model.predict([xtest, numXTest], verbose=0)

# %%
from sklearn.metrics import mean_squared_error as mse
print(mse(ytest, ypred))
print(mse(ytest, ypred)**0.5)
print(r2(ytest, ypred))
# Out:
# 1.2469380927280942
# 1.1166638226109478
# -0.20969173894228588

# %%
ytest[:100,0]
# Out:
# array([ 1.30599021,  1.33292937,  1.97048938,  1.93457051, -0.14872419,
#         0.59659245,  0.84802457,  1.16231472,  0.16556596,  0.0398499 ,
#         0.09372821,  0.12066737,  0.16556596,  0.00393103, -0.76832476,
#        -0.94791913, -0.28341996, -0.39117659, -1.39690506, -1.01077716,
#        -0.62464927, -0.62585736, -0.84331351, -1.06076966, -1.27822581,
#        -1.49568196, -0.35525771, -0.71444645,  0.01291075, -0.31035912,
#        -0.06790672,  0.05780934,  0.01291075,  0.65945048,  0.46189667,
#         0.1835254 ,  0.12964709,  0.4259778 , -0.40913602,  0.2823023 ,
#        -0.43607518, -0.43607518, -0.43607518, -0.70546673, -0.91200026,
#        -0.91388089, -1.25239511, -1.59090933, -1.92942354, -2.26793776,
#        -2.03446507, -1.45976309, -0.81322336,  0.97374063,  0.22842399,
#         0.40801836,  0.50679527,  0.67740992,  0.75822738,  0.60557217,
#         0.57863301,  0.8121057 ,  1.27905106, -0.13076475, -0.14872419,
#         0.93782175, -0.13974447,  0.65047076,  0.31822118,  0.44393724,
#        -0.31933884,  1.06353781, -0.24750109,  0.17454568,  0.89292316,
#         0.21944427,  0.33618061,  0.65945048,  0.3272009 ,  2.01538798,
#         1.09047697,  1.44068599,  1.17129444,  0.91986232,  0.47087639,
#         0.71332879,  1.95252995,  0.94680147,  1.17129444,  2.37457672,
#         0.73128823,  0.61455189, -0.4001563 , -0.42709546,  0.20148484,
#        -1.10057435,  0.07576878, -0.13974447,  0.22842399, -0.22056193])

# %%
plt.plot(ytest[:100,1])
plt.plot(ypred[:100,1])
plt.figlegend(["test","pred"])

# %%
data
# Out:
#                      % Iron Feed  % Silica Feed  Starch Flow  Amina Flow  \
pip = Pipeline([('constant', DropConstantFeatures(tol=0.90)), ('duplicate', DropDuplicateFeatures()), ('correlated', SmartCorrelatedSelection(threshold=0.8))])

df = pip.fit_transform(data.drop(['% Iron Concentrate','% Silica Concentrate'], axis=1))

# %%
df['% Iron Concentrate'] = data['% Iron Concentrate']
df['% Silica Concentrate'] = data['% Silica Concentrate']
df = df.reset_index()

# %%
df
# Out:
#                     date  % Silica Feed  Starch Flow  Amina Flow  \
# 0    2017-03-29 12:00:00           9.34  2044.990000     349.911
# 1    2017-03-29 13:00:00           9.34  2510.360000     306.635
# 2    2017-03-29 14:00:00           9.34  2138.230000     435.199
# 3    2017-03-29 15:00:00           9.34   458.079000     476.878
# 4    2017-03-29 16:00:00           9.56   145.349632     252.088
# ...                  ...            ...          ...         ...
# 3943 2017-09-09 19:00:00          23.20  2888.060000     494.990
# 3944 2017-09-09 20:00:00          23.20  4218.570000     492.027
# 3945 2017-09-09 21:00:00          23.20  3159.100000     520.986
# 3946 2017-09-09 22:00:00          23.20  3348.190000     511.961
# 3947 2017-09-09 23:00:00          23.20  2983.080000     461.285
#
#       Ore Pulp Flow  Ore Pulp pH  Ore Pulp Density  \
# 0        405.625000      9.74604          1.649650
# 1        402.303000      9.63786          1.524512
# 2        401.953000      9.61320          1.594940
# 3        400.173000      9.75149          1.638440
# 4        399.484000      9.96978          1.521080
# ...             ...          ...               ...
# 3943     376.468000      9.27990          1.667860
# 3944     378.630000      9.15799          1.648880
# 3945     381.468667      9.58069          1.736200
# 3946     379.684000      9.89000          1.737230
# 3947     378.691000      9.68117          1.689760
#
#       Flotation Column 03 Air Flow  Flotation Column 04 Air Flow  \
# 0                          201.826                       295.096
# 1                          201.929                       295.096
# 2                          198.605                       295.096
# 3                          199.265                       295.096
# 4                          201.251                       295.096
# ...                            ...                           ...
# 3943                       301.685                       300.583
# 3944                       300.543                       300.125
# 3945                       299.085                       299.130
# 3946                       298.231                       297.533
# 3947                       297.993                       299.707
#
#       Flotation Column 05 Air Flow  Flotation Column 06 Air Flow  \
# 0                          306.400                       250.601
# 1                          306.400                       250.194
# 2                          306.400                       250.460
# 3                          306.400                       247.809
# 4                          306.400                       250.488
# ...                            ...                           ...
# 3943                       300.593                       297.551
# 3944                       299.530                       336.250
# 3945                       299.588                       350.652
# 3946                       296.898                       346.723
# 3947                       298.301                       363.964
#
#       Flotation Column 01 Level  Flotation Column 02 Level  \
# 0                    555.264467                 552.255566
# 1                    851.772761                 809.863864
# 2                    850.510694                 774.266870
# 3                    858.052225                 778.343085
# 4                    853.745107                 782.419299
# ...                         ...                        ...
# 3943                 577.943000                 489.959000
# 3944                 412.491000                 510.388000
# 3945                 401.456000                 533.409000
# 3946                 399.186000                 520.956000
# 3947                 398.993000                 500.235000
#
#       Flotation Column 03 Level  Flotation Column 04 Level  \
# 0                    614.984714                    428.430
# 1                    881.307250                    447.543
# 2                    886.773000                    470.638
# 3                    883.777182                    438.033
# 4                    883.715800                    435.285
# ...                         ...                        ...
# 3943                 504.995000                    440.587
# 3944                 342.202000                    371.883
# 3945                 390.060000                    395.463
# 3946                 700.739000                    422.519
# 3947                 859.167000                    406.649
#
#       Flotation Column 05 Level  Flotation Column 06 Level  \
# 0                       413.662                    447.887
# 1                       421.279                    446.697
# 2                       455.341                    457.393
# 3                       446.859                    423.184
# 4                       434.663                    452.469
# ...                         ...                        ...
# 3943                    481.295                    434.701
# 3944                    594.518                    443.687
# 3945                    587.855                    489.406
# 3946                    585.371                    474.397
# 3947                    553.589                    372.992
#
#       Flotation Column 07 Level  % Iron Concentrate  % Silica Concentrate
# 0                       464.869               66.44                  1.36
# 1                       413.322               66.57                  1.43
# 2                       456.480               66.64                  1.33
# 3                       483.157               66.41                  1.27
# 4                       436.865               63.63                  5.50
# ...                         ...                 ...                   ...
# 3943                    401.796               65.05                  1.65
# 3944                    375.044               64.83                  1.71
# 3945                    504.982               64.29                  1.80
# 3946                    385.606               64.25                  1.96
# 3947                    396.832               64.27                  1.71
#
# [3948 rows x 20 columns]

# %%
import statsmodels.api as sm

# Separate time series and numerical data
ts_df = df[['date', '% Silica Concentrate', '% Iron Concentrate']]
num_df = df.drop(['% Silica Concentrate', '% Iron Concentrate'], axis = 1)

# Merge time series and numerical data
merged_df = pd.merge(ts_df, num_df, on='date')
merged_df = merged_df.set_index('date')

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm

# Separate time series and numerical data
ts_df = df[['date', '% Silica Concentrate', '% Iron Concentrate']]
num_df = df.drop(['% Silica Concentrate', '% Iron Concentrate'], axis = 1)

# Merge time series and numerical data
merged_df = pd.merge(ts_df, num_df, on='date')
merged_df = merged_df.set_index('date')

# Create lagged variables
for i in merged_df.columns:
    if i == 'date':
        continue
    merged_df[i+'_lag24'] = merged_df[i].shift(24)
    
# merged_df['y1_lag1'] = merged_df['y1'].shift(1)
# merged_df['x1_lag1'] = merged_df['x1'].shift(1)

# Remove NaN values
merged_df.dropna(inplace=True)
merged_df

# Define exogenous variables
exog = merged_df.drop(['% Silica Concentrate', '% Iron Concentrate', '% Silica Concentrate_lag24', '% Iron Concentrate_lag24'], axis = 1)
for i in exog.columns:
    if '_lag24' not in i:
        exog.drop(i, axis=1, inplace=True)

# Define endogenous variables
endog = merged_df[['% Silica Concentrate', '% Iron Concentrate', '% Silica Concentrate_lag24', '% Iron Concentrate_lag24']]

# Split data into training and testing sets
train_endog = endog[:-12]
test_endog = endog[-12:]

train_exog = exog[:-12]
test_exog = exog[-12:]

exog
# Out:
#                      % Silica Feed_lag24  Starch Flow_lag24  Amina Flow_lag24  \
# date
# 2017-03-30 12:00:00                 9.34        2044.990000        349.911000
# 2017-03-30 13:00:00                 9.34        2510.360000        306.635000
# 2017-03-30 14:00:00                 9.34        2138.230000        435.199000
# 2017-03-30 15:00:00                 9.34         458.079000        476.878000
# 2017-03-30 16:00:00                 9.56         145.349632        252.088000
# ...                                  ...                ...               ...
# 2017-09-09 19:00:00                 8.45        1404.620400        310.231000
# 2017-09-09 20:00:00                 8.45        1083.102632        268.753000
# 2017-09-09 21:00:00                 8.45        1483.016542        358.590000
# 2017-09-09 22:00:00                 8.45        3337.200000        250.652607
# 2017-09-09 23:00:00                 8.45        2850.860000        360.092000
#
#                      Ore Pulp Flow_lag24  Ore Pulp pH_lag24  \
# date
# 2017-03-30 12:00:00           405.625000            9.74604
# 2017-03-30 13:00:00           402.303000            9.63786
# 2017-03-30 14:00:00           401.953000            9.61320
max.py:161: EstimationWarning: Estimation of VARMA(p,q) models is not generically robust, due especially to identification issues.
#   warn('Estimation of VARMA(p,q) models is not generically robust,'
# D:\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   self._init_dates(dates, freq)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[227], line 2
#       1 model = sm.tsa.VARMAX(train_endog, exog=train_exog, order=(24,24), trend='c')
# ----> 2 results = model.fit(maxiter=1, disp=True)
#
# File D:\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py:704, in MLEModel.fit(self, start_params, transformed, includes_fixed, cov_type, cov_kwds, method, maxiter, full_output, disp, callback, return_params, optim_score, optim_complex_step, optim_hessian, flags, low_memory, **kwargs)
#     702         flags['hessian_method'] = optim_hessian
#     703     fargs = (flags,)
# --> 704     mlefit = super(MLEModel, self).fit(start_params, method=method,
#     705                                        fargs=fargs,
#     706                                        maxiter=maxiter,
#     707                                        full_output=full_output,
#     708                                        disp=disp, callback=callback,
#     709                                        skip_hessian=True, **kwargs)
#     711 # Just return the fitted parameters if requested
#     712 if return_params:
#
# File D:\lib\site-packages\statsmodels\base\model.py:566, in LikelihoodModel.fit(self, start_params, method, maxiter, full_output, disp, fargs, callback, retall, skip_hessian, **kwargs)
#     563     del kwargs["use_t"]
#     565 optimizer = Optimizer()
# --> 566 xopt, retvals, optim_settings = optimizer._fit(f, score, start_params,
#     567                                                fargs, kwargs,
#     568                                                hessian=hess,
#     569                                                method=method,
#     570                                                disp=disp,
#     571                                                maxiter=maxiter,
#     572                                                callback=callback,
#     573                                                retall=retall,
#     574                                                full_output=full_output)
#     575 # Restore cov_type, cov_kwds and use_t
#     576 optim_settings.update(kwds)
#
# File D:\lib\site-packages\statsmodels\base\optimizer.py:242, in Optimizer._fit(self, objective, gradient, start_params, fargs, kwargs, hessian, method, maxiter, full_output, disp, callback, retall)
#     239     fit_funcs.update(extra_fit_funcs)
#     241 func = fit_funcs[method]
# --> 242 xopt, retvals = func(objective, gradient, start_params, fargs, kwargs,
#     243                      disp=disp, maxiter=maxiter, callback=callback,
#     244                      retall=retall, full_output=full_output,
#     245                      hess=hessian)
#     247 optim_settings = {'optimizer': method, 'start_params': start_params,
#     248                   'maxiter': maxiter, 'full_output': full_output,
#     249                   'disp': disp, 'fargs': fargs, 'callback': callback,
#     250                   'retall': retall, "extra_fit_funcs": extra_fit_funcs}
#     251 optim_settings.update(kwargs)
#
# File D:\lib\site-packages\statsmodels\base\optimizer.py:659, in _fit_lbfgs(f, score, start_params, fargs, kwargs, disp, maxiter, callback, retall, full_output, hess)
#     656 elif approx_grad:
#     657     func = f
# --> 659 retvals = optimize.fmin_l_bfgs_b(func, start_params, maxiter=maxiter,
#     660                                  callback=callback, args=fargs,
#     661                                  bounds=bounds, disp=disp,
#     662                                  **extra_kwargs)
#     664 if full_output:
#     665     xopt, fopt, d = retvals
#
# File D:\lib\site-packages\scipy\optimize\_lbfgsb_py.py:197, in fmin_l_bfgs_b(func, x0, fprime, args, approx_grad, bounds, m, factr, pgtol, epsilon, iprint, maxfun, maxiter, disp, callback, maxls)
#     185 # build options
#     186 opts = {'disp': disp,
#     187         'iprint': iprint,
#     188         'maxcor': m,
#    (...)
#     194         'callback': callback,
#     195         'maxls': maxls}
# --> 197 res = _minimize_lbfgsb(fun, x0, args=args, jac=jac, bounds=bounds,
#     198                        **opts)
#     199 d = {'grad': res['jac'],
#     200      'task': res['message'],
#     201      'funcalls': res['nfev'],
#     202      'nit': res['nit'],
#     203      'warnflag': res['status']}
#     204 f = res['fun']
#
# File D:\lib\site-packages\scipy\optimize\_lbfgsb_py.py:305, in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, finite_diff_rel_step, **unknown_options)
#     302     else:
#     303         iprint = disp
# --> 305 sf = _prepare_scalar_function(fun, x0, jac=jac, args=args, epsilon=eps,
#     306                               bounds=new_bounds,
#     307                               finite_diff_rel_step=finite_diff_rel_step)
#     309 func_and_grad = sf.fun_and_grad
#     311 fortran_int = _lbfgsb.types.intvar.dtype
#
# File D:\lib\site-packages\scipy\optimize\_optimize.py:332, in _prepare_scalar_function(fun, x0, jac, args, bounds, epsilon, finite_diff_rel_step, hess)
#     328     bounds = (-np.inf, np.inf)
#     330 # ScalarFunction caches. Reuse of fun(x) during grad
#     331 # calculation reduces overall function evaluations.
# --> 332 sf = ScalarFunction(fun, x0, args, grad, hess,
#     333                     finite_diff_rel_step, bounds, epsilon=epsilon)
#     335 return sf
#
# File D:\lib\site-packages\scipy\optimize\_differentiable_functions.py:177, in ScalarFunction.__init__(self, fun, x0, args, grad, hess, finite_diff_rel_step, finite_diff_bounds, epsilon)
#     173         self.g = approx_derivative(fun_wrapped, self.x, f0=self.f,
#     174                                    **finite_diff_options)
#     176 self._update_grad_impl = update_grad
# --> 177 self._update_grad()
#     179 # Hessian Evaluation
#     180 if callable(hess):
#
# File D:\lib\site-packages\scipy\optimize\_differentiable_functions.py:256, in ScalarFunction._update_grad(self)
#     254 def _update_grad(self):
#     255     if not self.g_updated:
# --> 256         self._update_grad_impl()
#     257         self.g_updated = True
#
# File D:\lib\site-packages\scipy\optimize\_differentiable_functions.py:173, in ScalarFunction.__init__.<locals>.update_grad()
#     171 self._update_fun()
#     172 self.ngev += 1
# --> 173 self.g = approx_derivative(fun_wrapped, self.x, f0=self.f,
#     174                            **finite_diff_options)
#
# File D:\lib\site-packages\scipy\optimize\_numdiff.py:505, in approx_derivative(fun, x0, method, rel_step, abs_step, f0, bounds, sparsity, as_linear_operator, args, kwargs)
#     502     use_one_sided = False
#     504 if sparsity is None:
# --> 505     return _dense_difference(fun_wrapped, x0, f0, h,
#     506                              use_one_sided, method)
#     507 else:
#     508     if not issparse(sparsity) and len(sparsity) == 2:
#
# File D:\lib\site-packages\scipy\optimize\_numdiff.py:576, in _dense_difference(fun, x0, f0, h, use_one_sided, method)
#     574     x = x0 + h_vecs[i]
#     575     dx = x[i] - x0[i]  # Recompute dx as exactly representable number.
# --> 576     df = fun(x) - f0
#     577 elif method == '3-point' and use_one_sided[i]:
#     578     x1 = x0 + h_vecs[i]
#
# File D:\lib\site-packages\scipy\optimize\_numdiff.py:456, in approx_derivative.<locals>.fun_wrapped(x)
#     455 def fun_wrapped(x):
# --> 456     f = np.atleast_1d(fun(x, *args, **kwargs))
#     457     if f.ndim > 1:
#     458         raise RuntimeError("`fun` return value has "
#     459                            "more than 1 dimension.")
#
# File D:\lib\site-packages\scipy\optimize\_differentiable_functions.py:137, in ScalarFunction.__init__.<locals>.fun_wrapped(x)
#     133 self.nfev += 1
#     134 # Send a copy because the user may overwrite it.
#     135 # Overwriting results in undefined behaviour because
#     136 # fun(self.x) will change self.x, with the two no longer linked.
# --> 137 fx = fun(np.copy(x), *args)
#     138 # Make sure the function returns a true scalar
#     139 if not np.isscalar(fx):
#
# File D:\lib\site-packages\statsmodels\base\model.py:534, in LikelihoodModel.fit.<locals>.f(params, *args)
#     533 def f(params, *args):
# --> 534     return -self.loglike(params, *args) / nobs
#
# File D:\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py:939, in MLEModel.loglike(self, params, *args, **kwargs)
#     936 if complex_step:
#     937     kwargs['inversion_method'] = INVERT_UNIVARIATE | SOLVE_LU
# --> 939 loglike = self.ssm.loglike(complex_step=complex_step, **kwargs)
#     941 # Koopman, Shephard, and Doornik recommend maximizing the average
#     942 # likelihood to avoid scale issues, but the averaging is done
#     943 # automatically in the base model `fit` method
#     944 return loglike
#
# File D:\lib\site-packages\statsmodels\tsa\statespace\kalman_filter.py:1001, in KalmanFilter.loglike(self, **kwargs)
#     985 r"""
#     986 Calculate the loglikelihood associated with the statespace model.
#     987
#    (...)
#     997     The joint loglikelihood.
#     998 """
#     999 kwargs.setdefault('conserve_memory',
#    1000                   MEMORY_CONSERVE ^ MEMORY_NO_LIKELIHOOD)
# -> 1001 kfilter = self._filter(**kwargs)
#    1002 loglikelihood_burn = kwargs.get('loglikelihood_burn',
#    1003                                 self.loglikelihood_burn)
#    1004 if not (kwargs['conserve_memory'] & MEMORY_NO_LIKELIHOOD):
#
# KeyboardInterrupt:

# %%
model = sm.tsa.VARMAX(train_endog, exog=train_exog, order=(24,24), trend='c')
results = model.fit(maxiter=10, disp=True)

# %%
model = sm.tsa.VARMAX(train_endog, exog=train_exog, order=(24,24), trend='c')
results = model.fit(maxiter=100, disp=True)

# %%
predictions = results.forecast(steps=len(test_endog), exog=test_exog)

# Evaluate model
mse1 = np.mean((predictions['% Silica Concentrate_hat'] - test_endog['% Silica Concentrate'])**2)
mse2 = np.mean((predictions['% Iron Concentrate_hat'] - test_endog['% Iron Concentrate'])**2)

# %%
mse1, mse2
